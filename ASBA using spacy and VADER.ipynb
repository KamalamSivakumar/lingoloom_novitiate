# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# sentences = [
#   'The food we had yesterday was delicious',
#   'My time in Italy was very enjoyable',
#   'I found the meal to be tasty',
#   'The internet was slow.',
#   'Our experience was suboptimal',
#   'The T-Shirt was dirty.'
# ] # Sample sentences

# %%
from datasets import load_dataset
reviews = load_dataset("tomaarsen/setfit-absa-semeval-restaurants", split="train[:128]")
df = reviews.to_pandas()

sentences = df['text']

# %%
sentences
# Out:
# 0                   But the staff was so horrible to us.
# 1      To be completely fair, the only redeeming fact...
# 2      The food is uniformly exceptional, with a very...
# 3      The food is uniformly exceptional, with a very...
# 4      The food is uniformly exceptional, with a very...
#                              ...
# 123    Right off the L in Brooklyn this is a nice coz...
# 124    Right off the L in Brooklyn this is a nice coz...
# 125    Le Pere Pinard has a $15 pre-theater menu that...
# 126    I also ordered for delivery and the restaurant...
# 127    I also ordered for delivery and the restaurant...
# Name: text, Length: 128, dtype: object

# %%
for sentence in sentences:
  doc = nlp(sentence)
  for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_, token.pos_, [child for child in token.children])
# Out:
# But cc was AUX CCONJ []
# the det staff NOUN DET []
# staff nsubj was AUX NOUN [the]
# was ROOT was AUX AUX [But, staff, horrible, .]
# so advmod horrible ADJ ADV []
# horrible acomp was AUX ADJ [so, to]
# to prep horrible ADJ ADP [us]
# us pobj to ADP PRON []
# . punct was AUX PUNCT []
# To aux be AUX PART []
# be advcl was AUX AUX [To, fair]
# completely advmod fair ADJ ADV []
# fair acomp be AUX ADJ [completely]
# , punct was AUX PUNCT []
# the det factor NOUN DET []
# only amod factor NOUN ADJ []
# redeeming amod factor NOUN VERB []
# factor nsubj was AUX NOUN [the, only, redeeming]
# was ROOT was AUX AUX [be, ,, factor, food, ,, but, make, .]
# the det food NOUN DET []
# food attr was AUX NOUN [the, ,, was]
# , punct food NOUN PUNCT []
# which nsubj was AUX PRON []
# was relcl food NOUN AUX [which, above]
# above prep was AUX ADP [average]
# average pobj above ADP ADJ []
# , punct was AUX PUNCT []
# but cc was AUX CCONJ []
# could aux make VERB AUX []
# n't neg make VERB PART []
# make conj was AUX VERB [could, n't, up, for]
# up prt make VERB ADP []
# for prep make VERB ADP [deficiencies]
# all predet deficiencies NOUN DET []
# the det deficiencies NOUN DET []
# other amod deficiencies NOUN ADJ []
# deficiencies pobj for ADP NOUN [all, the, other, of]
# of prep deficiencies NOUN ADP [Teodora]
# Teodora pobj of ADP PROPN []
# . punct was AUX PUNCT []
# The det food NOUN DET []
# food nsubj is AUX NOUN [The]
# is ROOT is AUX AUX [food, exceptional, ,, with, ,, 's, .]
# uniformly advmod exceptional ADJ ADV []
# exceptional acomp is AUX ADJ [uniformly]
# , punct is AUX PUNCT []
# with prep is AUX ADP [kitchen]
# a det kitchen NOUN DET []
# very advmod capable ADJ ADV []
# capable amod kitchen NOUN ADJ [very]
# kitchen pobj with ADP NOUN [a, capable, whip]
# which nsubj whip VERB PRON []
# will aux whip VERB AUX []
# proudly advmod whip VERB ADV []
# whip relcl kitchen NOUN VERB [which, will, proudly, up, feel]
# up prt whip VERB ADP []
# whatever dobj feel VERB PRON []
# you nsubj feel VERB PRON []
# feel ccomp whip VERB VERB [whatever, you, like]
# like prep feel VERB ADP [eating]
# eating pobj like ADP VERB []
# , punct is AUX PUNCT []
# whether mark 's AUX SCONJ []
# it nsubj 's AUX PRON []
# 's advcl is AUX AUX [whether, it, on, not]
# on prep 's AUX ADP [menu, or]
# the det menu NOUN DET []
# menu pobj on ADP NOUN [the]
# or cc on ADP CCONJ []
# not neg 's AUX PART []
# . punct is AUX PUNCT []
# The det food NOUN DET []
# food nsubj is AUX NOUN [The]
# is ROOT is AUX AUX [food, exceptional, ,, with, ,, 's, .]
# uniformly advmod exceptional ADJ ADV []
# exceptional acomp is AUX ADJ [uniformly]
# , punct is AUX PUNCT []
# with prep is AUX ADP [kitchen]
# a det kitchen NOUN DET []
# very advmod capable ADJ ADV []
# capable amod kitchen NOUN ADJ [very]
# kitchen pobj with ADP NOUN [a, capable, whip]
# which nsubj whip VERB PRON []
# will aux whip VERB AUX []
# proudly advmod whip VERB ADV []
# whip relcl kitchen NOUN VERB [which, will, proudly, up, feel]
# up prt whip VERB ADP []
# whatever dobj feel VERB PRON []
# you nsubj feel VERB PRON []
# feel ccomp whip VERB VERB [whatever, you, like]
# like prep feel VERB ADP [eating]
# eating pobj like ADP VERB []
# , punct is AUX PUNCT []
# whether mark 's AUX SCONJ []
# it nsubj 's AUX PRON []
# 's advcl is AUX AUX [whether, it, on, not]
# on prep 's AUX ADP [menu, or]
# the det menu NOUN DET []
# menu pobj on ADP NOUN [the]
# or cc on ADP CCONJ []
# not neg 's AUX PART []
# . punct is AUX PUNCT []
# The det food NOUN DET []
# food nsubj is AUX NOUN [The]
# is ROOT is AUX AUX [food, exceptional, ,, with, ,, 's, .]
# uniformly advmod exceptional ADJ ADV []
# exceptional acomp is AUX ADJ [uniformly]
# , punct is AUX PUNCT []
# with prep is AUX ADP [kitchen]
# a det kitchen NOUN DET []
# very advmod capable ADJ ADV []
# capable amod kitchen NOUN ADJ [very]
# kitchen pobj with ADP NOUN [a, capable, whip]
# which nsubj whip VERB PRON []
# will aux whip VERB AUX []
# proudly advmod whip VERB ADV []
# whip relcl kitchen NOUN VERB [which, will, proudly, up, feel]
# up prt whip VERB ADP []
# whatever dobj feel VERB PRON []
# you nsubj feel VERB PRON []
# feel ccomp whip VERB VERB [whatever, you, like]
# like prep feel VERB ADP [eating]
# eating pobj like ADP VERB []
# , punct is AUX PUNCT []
# whether mark 's AUX SCONJ []
# it nsubj 's AUX PRON []
# 's advcl is AUX AUX [whether, it, on, not]
# on prep 's AUX ADP [menu, or]
# the det menu NOUN DET []
# menu pobj on ADP NOUN [the]
# or cc on ADP CCONJ []
# not neg 's AUX PART []
# . punct is AUX PUNCT []
# Not preconj was AUX PART [only]
# only advmod Not PART ADV []
# was ROOT was AUX AUX [Not, food, ,, but, were, .]
# the det food NOUN DET []
# food nsubj was AUX NOUN [the, outstanding]
# outstanding amod food NOUN ADJ []
# , punct was AUX PUNCT []
# but cc was AUX CCONJ []
# the det perks NOUN DET []
# little amod perks NOUN ADJ []
# ' punct perks NOUN PUNCT []
# perks nsubj were AUX NOUN [the, little, ', ']
# ' punct perks NOUN PUNCT []
# were conj was AUX AUX [perks, great]
# great acomp were AUX ADJ []
# . punct was AUX PUNCT []
# Not preconj was AUX PART [only]
# only advmod Not PART ADV []
# was ROOT was AUX AUX [Not, food, ,, but, were, .]
# the det food NOUN DET []
# food nsubj was AUX NOUN [the, outstanding]
# outstanding amod food NOUN ADJ []
# , punct was AUX PUNCT []
# but cc was AUX CCONJ []
# the det perks NOUN DET []
# little amod perks NOUN ADJ []
# ' punct perks NOUN PUNCT []
# perks nsubj were AUX NOUN [the, little, ', ']
# ' punct perks NOUN PUNCT []
# were conj was AUX AUX [perks, great]
# great acomp were AUX ADJ []
# . punct was AUX PUNCT []
# Our poss favorite NOUN PRON []
# agreed amod favorite NOUN VERB []
# favorite nsubj is AUX NOUN [Our, agreed]
# is ROOT is AUX AUX [favorite, orrechiete, are, .]
# the det orrechiete NOUN DET []
# orrechiete attr is AUX NOUN [the, with]
# with prep orrechiete NOUN ADP [sausage]
# sausage pobj with ADP NOUN [and, chicken]
# and cc sausage NOUN CCONJ []
# chicken conj sausage NOUN NOUN []
# ( punct are AUX PUNCT []
# usually advmod are AUX ADV []
# the det waiters NOUN DET []
# waiters nsubj are AUX NOUN [the]
# are parataxis is AUX AUX [(, usually, waiters, kind, get, )]
# kind acomp are AUX ADJ [enough, split]
# enough advmod kind ADJ ADJ []
# to aux split VERB PART []
# split xcomp kind ADJ VERB [to, dish, in]
# the det dish NOUN DET []
# dish dobj split VERB NOUN [the]
# in prep split VERB ADP [half]
# half pobj in ADP NOUN []
# so mark get VERB SCONJ []
# you nsubj get VERB PRON []
# get advcl are AUX VERB [so, you, sample]
# to aux sample VERB PART []
# sample xcomp get VERB VERB [to, meats]
# both det meats NOUN DET []
# meats dobj sample VERB NOUN [both]
# ) punct are AUX PUNCT []
# . punct is AUX PUNCT []
# Our poss favorite NOUN PRON []
# agreed amod favorite NOUN VERB []
# favorite nsubj is AUX NOUN [Our, agreed]
# is ROOT is AUX AUX [favorite, orrechiete, are, .]
# the det orrechiete NOUN DET []
# orrechiete attr is AUX NOUN [the, with]
# with prep orrechiete NOUN ADP [sausage]
# sausage pobj with ADP NOUN [and, chicken]
# and cc sausage NOUN CCONJ []
# chicken conj sausage NOUN NOUN []
# ( punct are AUX PUNCT []
# usually advmod are AUX ADV []
# the det waiters NOUN DET []
# waiters nsubj are AUX NOUN [the]
# are parataxis is AUX AUX [(, usually, waiters, kind, get, )]
# kind acomp are AUX ADJ [enough, split]
# enough advmod kind ADJ ADJ []
# to aux split VERB PART []
# split xcomp kind ADJ VERB [to, dish, in]
# the det dish NOUN DET []
# dish dobj split VERB NOUN [the]
# in prep split VERB ADP [half]
# half pobj in ADP NOUN []
# so mark get VERB SCONJ []
# you nsubj get VERB PRON []
# get advcl are AUX VERB [so, you, sample]
# to aux sample VERB PART []
# sample xcomp get VERB VERB [to, meats]
# both det meats NOUN DET []
# meats dobj sample VERB NOUN [both]
# ) punct are AUX PUNCT []
# . punct is AUX PUNCT []
# Our poss favorite NOUN PRON []
# agreed amod favorite NOUN VERB []
# favorite nsubj is AUX NOUN [Our, agreed]
# is ROOT is AUX AUX [favorite, orrechiete, are, .]
# the det orrechiete NOUN DET []
# orrechiete attr is AUX NOUN [the, with]
# with prep orrechiete NOUN ADP [sausage]
# sausage pobj with ADP NOUN [and, chicken]
# and cc sausage NOUN CCONJ []
# chicken conj sausage NOUN NOUN []
# ( punct are AUX PUNCT []
# usually advmod are AUX ADV []
# the det waiters NOUN DET []
# waiters nsubj are AUX NOUN [the]
# are parataxis is AUX AUX [(, usually, waiters, kind, get, )]
# kind acomp are AUX ADJ [enough, split]
# enough advmod kind ADJ ADJ []
# to aux split VERB PART []
# split xcomp kind ADJ VERB [to, dish, in]
# the det dish NOUN DET []
# dish dobj split VERB NOUN [the]
# in prep split VERB ADP [half]
# half pobj in ADP NOUN []
# so mark get VERB SCONJ []
# you nsubj get VERB PRON []
# get advcl are AUX VERB [so, you, sample]
# to aux sample VERB PART []
# sample xcomp get VERB VERB [to, meats]
# both det meats NOUN DET []
# meats dobj sample VERB NOUN [both]
# ) punct are AUX PUNCT []
# . punct is AUX PUNCT []
# Our poss favorite NOUN PRON []
# agreed amod favorite NOUN VERB []
# favorite nsubj is AUX NOUN [Our, agreed]
# is ROOT is AUX AUX [favorite, orrechiete, are, .]
# the det orrechiete NOUN DET []
# orrechiete attr is AUX NOUN [the, with]
# with prep orrechiete NOUN ADP [sausage]
# sausage pobj with ADP NOUN [and, chicken]
# and cc sausage NOUN CCONJ []
# chicken conj sausage NOUN NOUN []
# ( punct are AUX PUNCT []
# usually advmod are AUX ADV []
# the det waiters NOUN DET []
# waiters nsubj are AUX NOUN [the]
# are parataxis is AUX AUX [(, usually, waiters, kind, get, )]
# kind acomp are AUX ADJ [enough, split]
# enough advmod kind ADJ ADJ []
# to aux split VERB PART []
# split xcomp kind ADJ VERB [to, dish, in]
# the det dish NOUN DET []
# dish dobj split VERB NOUN [the]
# in prep split VERB ADP [half]
# half pobj in ADP NOUN []
# so mark get VERB SCONJ []
# you nsubj get VERB PRON []
# get advcl are AUX VERB [so, you, sample]
# to aux sample VERB PART []
# sample xcomp get VERB VERB [to, meats]
# both det meats NOUN DET []
# meats dobj sample VERB NOUN [both]
# ) punct are AUX PUNCT []
# . punct is AUX PUNCT []
# The det Bagels PROPN DET []
# Bagels nsubj have VERB PROPN [The]
# have ccomp gummy ADJ VERB [Bagels, taste]
# an det taste NOUN DET []
# outstanding amod taste NOUN ADJ []
# taste dobj have VERB NOUN [an, outstanding, with]
# with prep taste NOUN ADP [texture]
# a det texture NOUN DET []
# terrific amod texture NOUN ADJ []
# texture pobj with ADP NOUN [a, terrific]
# , punct gummy ADJ PUNCT []
# both det chewy NOUN DET []
# chewy nsubj gummy ADJ NOUN [both, yet]
# yet advmod chewy NOUN ADV []
# not neg gummy ADJ PART []
# gummy ROOT gummy ADJ ADJ [have, ,, chewy, not, .]
# . punct gummy ADJ PUNCT []
# Nevertheless advmod is AUX ADV []
# the det food NOUN DET []
# food nsubj is AUX NOUN [the, itself]
# itself appos food NOUN PRON []
# is ROOT is AUX AUX [Nevertheless, food, good, .]
# pretty advmod good ADJ ADV []
# good acomp is AUX ADJ [pretty]
# . punct is AUX PUNCT []
# They nsubj have VERB PRON []
# did aux have VERB AUX []
# not neg have VERB PART []
# have ROOT have VERB VERB [They, did, not, mayonnaise, ,, forgot, was, .]
# mayonnaise dobj have VERB NOUN []
# , punct have VERB PUNCT []
# forgot conj have VERB VERB [toast, ,, left]
# our poss toast NOUN PRON []
# toast dobj forgot VERB NOUN [our]
# , punct forgot VERB PUNCT []
# left conj forgot VERB VERB [out, ingredients]
# out prt left VERB ADP []
# ingredients dobj left VERB NOUN [(, cheese, ,, below]
# ( punct ingredients NOUN PUNCT []
# ie amod cheese NOUN X []
# cheese appos ingredients NOUN NOUN [ie, in, )]
# in prep cheese NOUN ADP [omelet]
# an det omelet NOUN DET []
# omelet pobj in ADP NOUN [an]
# ) punct cheese NOUN PUNCT []
# , punct ingredients NOUN PUNCT []
# below prep ingredients NOUN ADP [temperatures]
# hot amod temperatures NOUN ADJ []
# temperatures pobj below ADP NOUN [hot, and, bacon]
# and cc temperatures NOUN CCONJ []
# the det bacon NOUN DET []
# bacon conj temperatures NOUN NOUN [the]
# was conj have VERB AUX [cooked]
# so advmod over ADV ADV []
# over advmod cooked VERB ADV [so]
# cooked acomp was AUX VERB [over, crumbled]
# it nsubj crumbled VERB PRON []
# crumbled ccomp cooked VERB VERB [it, on, touched]
# on prep crumbled VERB ADP [plate]
# the det plate NOUN DET []
# plate pobj on ADP NOUN [the]
# when advmod touched VERB SCONJ []
# you nsubj touched VERB PRON []
# touched advcl crumbled VERB VERB [when, you, it]
# it dobj touched VERB PRON []
# . punct have VERB PUNCT []
# They nsubj have VERB PRON []
# did aux have VERB AUX []
# not neg have VERB PART []
# have ROOT have VERB VERB [They, did, not, mayonnaise, ,, forgot, was, .]
# mayonnaise dobj have VERB NOUN []
# , punct have VERB PUNCT []
# forgot conj have VERB VERB [toast, ,, left]
# our poss toast NOUN PRON []
# toast dobj forgot VERB NOUN [our]
# , punct forgot VERB PUNCT []
# left conj forgot VERB VERB [out, ingredients]
# out prt left VERB ADP []
# ingredients dobj left VERB NOUN [(, cheese, ,, below]
# ( punct ingredients NOUN PUNCT []
# ie amod cheese NOUN X []
# cheese appos ingredients NOUN NOUN [ie, in, )]
# in prep cheese NOUN ADP [omelet]
# an det omelet NOUN DET []
# omelet pobj in ADP NOUN [an]
# ) punct cheese NOUN PUNCT []
# , punct ingredients NOUN PUNCT []
# below prep ingredients NOUN ADP [temperatures]
# hot amod temperatures NOUN ADJ []
# temperatures pobj below ADP NOUN [hot, and, bacon]
# and cc temperatures NOUN CCONJ []
# the det bacon NOUN DET []
# bacon conj temperatures NOUN NOUN [the]
# was conj have VERB AUX [cooked]
# so advmod over ADV ADV []
# over advmod cooked VERB ADV [so]
# cooked acomp was AUX VERB [over, crumbled]
# it nsubj crumbled VERB PRON []
# crumbled ccomp cooked VERB VERB [it, on, touched]
# on prep crumbled VERB ADP [plate]
# the det plate NOUN DET []
# plate pobj on ADP NOUN [the]
# when advmod touched VERB SCONJ []
# you nsubj touched VERB PRON []
# touched advcl crumbled VERB VERB [when, you, it]
# it dobj touched VERB PRON []
# . punct have VERB PUNCT []
# They nsubj have VERB PRON []
# did aux have VERB AUX []
# not neg have VERB PART []
# have ROOT have VERB VERB [They, did, not, mayonnaise, ,, forgot, was, .]
# mayonnaise dobj have VERB NOUN []
# , punct have VERB PUNCT []
# forgot conj have VERB VERB [toast, ,, left]
# our poss toast NOUN PRON []
# toast dobj forgot VERB NOUN [our]
# , punct forgot VERB PUNCT []
# left conj forgot VERB VERB [out, ingredients]
# out prt left VERB ADP []
# ingredients dobj left VERB NOUN [(, cheese, ,, below]
# ( punct ingredients NOUN PUNCT []
# ie amod cheese NOUN X []
# cheese appos ingredients NOUN NOUN [ie, in, )]
# in prep cheese NOUN ADP [omelet]
# an det omelet NOUN DET []
# omelet pobj in ADP NOUN [an]
# ) punct cheese NOUN PUNCT []
# , punct ingredients NOUN PUNCT []
# below prep ingredients NOUN ADP [temperatures]
# hot amod temperatures NOUN ADJ []
# temperatures pobj below ADP NOUN [hot, and, bacon]
# and cc temperatures NOUN CCONJ []
# the det bacon NOUN DET []
# bacon conj temperatures NOUN NOUN [the]
# was conj have VERB AUX [cooked]
# so advmod over ADV ADV []
# over advmod cooked VERB ADV [so]
# cooked acomp was AUX VERB [over, crumbled]
# it nsubj crumbled VERB PRON []
# crumbled ccomp cooked VERB VERB [it, on, touched]
# on prep crumbled VERB ADP [plate]
# the det plate NOUN DET []
# plate pobj on ADP NOUN [the]
# when advmod touched VERB SCONJ []
# you nsubj touched VERB PRON []
# touched advcl crumbled VERB VERB [when, you, it]
# it dobj touched VERB PRON []
# . punct have VERB PUNCT []
# They nsubj have VERB PRON []
# did aux have VERB AUX []
# not neg have VERB PART []
# have ROOT have VERB VERB [They, did, not, mayonnaise, ,, forgot, was, .]
# mayonnaise dobj have VERB NOUN []
# , punct have VERB PUNCT []
# forgot conj have VERB VERB [toast, ,, left]
# our poss toast NOUN PRON []
# toast dobj forgot VERB NOUN [our]
# , punct forgot VERB PUNCT []
# left conj forgot VERB VERB [out, ingredients]
# out prt left VERB ADP []
# ingredients dobj left VERB NOUN [(, cheese, ,, below]
# ( punct ingredients NOUN PUNCT []
# ie amod cheese NOUN X []
# cheese appos ingredients NOUN NOUN [ie, in, )]
# in prep cheese NOUN ADP [omelet]
# an det omelet NOUN DET []
# omelet pobj in ADP NOUN [an]
# ) punct cheese NOUN PUNCT []
# , punct ingredients NOUN PUNCT []
# below prep ingredients NOUN ADP [temperatures]
# hot amod temperatures NOUN ADJ []
# temperatures pobj below ADP NOUN [hot, and, bacon]
# and cc temperatures NOUN CCONJ []
# the det bacon NOUN DET []
# bacon conj temperatures NOUN NOUN [the]
# was conj have VERB AUX [cooked]
# so advmod over ADV ADV []
# over advmod cooked VERB ADV [so]
# cooked acomp was AUX VERB [over, crumbled]
# it nsubj crumbled VERB PRON []
# crumbled ccomp cooked VERB VERB [it, on, touched]
# on prep crumbled VERB ADP [plate]
# the det plate NOUN DET []
# plate pobj on ADP NOUN [the]
# when advmod touched VERB SCONJ []
# you nsubj touched VERB PRON []
# touched advcl crumbled VERB VERB [when, you, it]
# it dobj touched VERB PRON []
# . punct have VERB PUNCT []
# They nsubj have VERB PRON []
# did aux have VERB AUX []
# not neg have VERB PART []
# have ROOT have VERB VERB [They, did, not, mayonnaise, ,, forgot, was, .]
# mayonnaise dobj have VERB NOUN []
# , punct have VERB PUNCT []
# forgot conj have VERB VERB [toast, ,, left]
# our poss toast NOUN PRON []
# toast dobj forgot VERB NOUN [our]
# , punct forgot VERB PUNCT []
# left conj forgot VERB VERB [out, ingredients]
# out prt left VERB ADP []
# ingredients dobj left VERB NOUN [(, cheese, ,, below]
# ( punct ingredients NOUN PUNCT []
# ie amod cheese NOUN X []
# cheese appos ingredients NOUN NOUN [ie, in, )]
# in prep cheese NOUN ADP [omelet]
# an det omelet NOUN DET []
# omelet pobj in ADP NOUN [an]
# ) punct cheese NOUN PUNCT []
# , punct ingredients NOUN PUNCT []
# below prep ingredients NOUN ADP [temperatures]
# hot amod temperatures NOUN ADJ []
# temperatures pobj below ADP NOUN [hot, and, bacon]
# and cc temperatures NOUN CCONJ []
# the det bacon NOUN DET []
# bacon conj temperatures NOUN NOUN [the]
# was conj have VERB AUX [cooked]
# so advmod over ADV ADV []
# over advmod cooked VERB ADV [so]
# cooked acomp was AUX VERB [over, crumbled]
# it nsubj crumbled VERB PRON []
# crumbled ccomp cooked VERB VERB [it, on, touched]
# on prep crumbled VERB ADP [plate]
# the det plate NOUN DET []
# plate pobj on ADP NOUN [the]
# when advmod touched VERB SCONJ []
# you nsubj touched VERB PRON []
# touched advcl crumbled VERB VERB [when, you, it]
# it dobj touched VERB PRON []
# . punct have VERB PUNCT []
# They nsubj have VERB PRON []
# did aux have VERB AUX []
# not neg have VERB PART []
# have ROOT have VERB VERB [They, did, not, mayonnaise, ,, forgot, was, .]
# mayonnaise dobj have VERB NOUN []
# , punct have VERB PUNCT []
# forgot conj have VERB VERB [toast, ,, left]
# our poss toast NOUN PRON []
# toast dobj forgot VERB NOUN [our]
# , punct forgot VERB PUNCT []
# left conj forgot VERB VERB [out, ingredients]
# out prt left VERB ADP []
# ingredients dobj left VERB NOUN [(, cheese, ,, below]
# ( punct ingredients NOUN PUNCT []
# ie amod cheese NOUN X []
# cheese appos ingredients NOUN NOUN [ie, in, )]
# in prep cheese NOUN ADP [omelet]
# an det omelet NOUN DET []
# omelet pobj in ADP NOUN [an]
# ) punct cheese NOUN PUNCT []
# , punct ingredients NOUN PUNCT []
# below prep ingredients NOUN ADP [temperatures]
# hot amod temperatures NOUN ADJ []
# temperatures pobj below ADP NOUN [hot, and, bacon]
# and cc temperatures NOUN CCONJ []
# the det bacon NOUN DET []
# bacon conj temperatures NOUN NOUN [the]
# was conj have VERB AUX [cooked]
# so advmod over ADV ADV []
# over advmod cooked VERB ADV [so]
# cooked acomp was AUX VERB [over, crumbled]
# it nsubj crumbled VERB PRON []
# crumbled ccomp cooked VERB VERB [it, on, touched]
# on prep crumbled VERB ADP [plate]
# the det plate NOUN DET []
# plate pobj on ADP NOUN [the]
# when advmod touched VERB SCONJ []
# you nsubj touched VERB PRON []
# touched advcl crumbled VERB VERB [when, you, it]
# it dobj touched VERB PRON []
# . punct have VERB PUNCT []
# They nsubj have VERB PRON []
# did aux have VERB AUX []
# not neg have VERB PART []
# have ROOT have VERB VERB [They, did, not, mayonnaise, ,, forgot, was, .]
# mayonnaise dobj have VERB NOUN []
# , punct have VERB PUNCT []
# forgot conj have VERB VERB [toast, ,, left]
# our poss toast NOUN PRON []
# toast dobj forgot VERB NOUN [our]
# , punct forgot VERB PUNCT []
# left conj forgot VERB VERB [out, ingredients]
# out prt left VERB ADP []
# ingredients dobj left VERB NOUN [(, cheese, ,, below]
# ( punct ingredients NOUN PUNCT []
# ie amod cheese NOUN X []
# cheese appos ingredients NOUN NOUN [ie, in, )]
# in prep cheese NOUN ADP [omelet]
# an det omelet NOUN DET []
# omelet pobj in ADP NOUN [an]
# ) punct cheese NOUN PUNCT []
# , punct ingredients NOUN PUNCT []
# below prep ingredients NOUN ADP [temperatures]
# hot amod temperatures NOUN ADJ []
# temperatures pobj below ADP NOUN [hot, and, bacon]
# and cc temperatures NOUN CCONJ []
# the det bacon NOUN DET []
# bacon conj temperatures NOUN NOUN [the]
# was conj have VERB AUX [cooked]
# so advmod over ADV ADV []
# over advmod cooked VERB ADV [so]
# cooked acomp was AUX VERB [over, crumbled]
# it nsubj crumbled VERB PRON []
# crumbled ccomp cooked VERB VERB [it, on, touched]
# on prep crumbled VERB ADP [plate]
# the det plate NOUN DET []
# plate pobj on ADP NOUN [the]
# when advmod touched VERB SCONJ []
# you nsubj touched VERB PRON []
# touched advcl crumbled VERB VERB [when, you, it]
# it dobj touched VERB PRON []
# . punct have VERB PUNCT []
# It nsubj took VERB PRON []
# took ROOT took VERB VERB [It, hour, get, !]
# half predet hour NOUN DET []
# an det hour NOUN DET []
# hour dobj took VERB NOUN [half, an]
# to aux get VERB PART []
# get xcomp took VERB VERB [to, check, ,, have]
# our poss check NOUN PRON []
# check dobj get VERB NOUN [our, ,, was]
# , punct check NOUN PUNCT []
# which nsubj was AUX PRON []
# was relcl check NOUN AUX [which, perfect, sit]
# perfect acomp was AUX ADJ []
# since mark sit VERB SCONJ []
# we nsubj sit VERB PRON []
# could aux sit VERB AUX []
# sit advcl was AUX VERB [since, we, could]
# , punct get VERB PUNCT []
# have conj get VERB VERB [drinks]
# drinks dobj have VERB NOUN [and, talk]
# and cc drinks NOUN CCONJ []
# talk conj drinks NOUN VERB []
# ! punct took VERB PUNCT []
# It nsubj took VERB PRON []
# took ROOT took VERB VERB [It, hour, get, !]
# half predet hour NOUN DET []
# an det hour NOUN DET []
# hour dobj took VERB NOUN [half, an]
# to aux get VERB PART []
# get xcomp took VERB VERB [to, check, ,, have]
# our poss check NOUN PRON []
# check dobj get VERB NOUN [our, ,, was]
# , punct check NOUN PUNCT []
# which nsubj was AUX PRON []
# was relcl check NOUN AUX [which, perfect, sit]
# perfect acomp was AUX ADJ []
# since mark sit VERB SCONJ []
# we nsubj sit VERB PRON []
# could aux sit VERB AUX []
# sit advcl was AUX VERB [since, we, could]
# , punct get VERB PUNCT []
# have conj get VERB VERB [drinks]
# drinks dobj have VERB NOUN [and, talk]
# and cc drinks NOUN CCONJ []
# talk conj drinks NOUN VERB []
# ! punct took VERB PUNCT []
# The det design NOUN DET []
# design nsubj is AUX NOUN [The, and, atmosphere]
# and cc design NOUN CCONJ []
# atmosphere conj design NOUN NOUN []
# is ROOT is AUX AUX [design, good, .]
# just advmod good ADJ ADV []
# as advmod good ADJ ADV []
# good acomp is AUX ADJ [just, as]
# . punct is AUX PUNCT []
# The det design NOUN DET []
# design nsubj is AUX NOUN [The, and, atmosphere]
# and cc design NOUN CCONJ []
# atmosphere conj design NOUN NOUN []
# is ROOT is AUX AUX [design, good, .]
# just advmod good ADJ ADV []
# as advmod good ADJ ADV []
# good acomp is AUX ADJ [just, as]
# . punct is AUX PUNCT []
# He nsubj visited VERB PRON []
# has aux visited VERB AUX []
# visited ROOT visited VERB VERB [He, has, Thailand, and, is, .]
# Thailand dobj visited VERB PROPN []
# and cc visited VERB CCONJ []
# is conj visited VERB AUX [expert]
# quite advmod expert NOUN ADV []
# expert attr is AUX NOUN [quite, on]
# on prep expert NOUN ADP [cuisine]
# the det cuisine NOUN DET []
# cuisine pobj on ADP NOUN [the]
# . punct visited VERB PUNCT []
# The det pizza NOUN DET []
# pizza nsubj is AUX NOUN [The]
# is ROOT is AUX AUX [pizza, best, like, .]
# the det best ADJ DET []
# best attr is AUX ADJ [the]
# if mark like VERB SCONJ []
# you nsubj like VERB PRON []
# like advcl is AUX VERB [if, you, pizza]
# thin amod pizza NOUN ADJ []
# crusted amod pizza NOUN VERB []
# pizza dobj like VERB NOUN [thin, crusted]
# . punct is AUX PUNCT []
# The det pizza NOUN DET []
# pizza nsubj is AUX NOUN [The]
# is ROOT is AUX AUX [pizza, best, like, .]
# the det best ADJ DET []
# best attr is AUX ADJ [the]
# if mark like VERB SCONJ []
# you nsubj like VERB PRON []
# like advcl is AUX VERB [if, you, pizza]
# thin amod pizza NOUN ADJ []
# crusted amod pizza NOUN VERB []
# pizza dobj like VERB NOUN [thin, crusted]
# . punct is AUX PUNCT []
# All predet money NOUN DET []
# the det money NOUN DET []
# money nsubj went VERB NOUN [All, the]
# went ccomp went VERB VERB [money, into]
# into prep went VERB ADP [decoration]
# the det decoration NOUN DET []
# interior amod decoration NOUN ADJ []
# decoration pobj into ADP NOUN [the, interior]
# , punct went VERB PUNCT []
# none nsubj went VERB NOUN [of]
# of prep none NOUN ADP [it]
# it pobj of ADP PRON []
# went ROOT went VERB VERB [went, ,, none, to, .]
# to prep went VERB ADP [chefs]
# the det chefs NOUN DET []
# chefs pobj to ADP NOUN [the]
# . punct went VERB PUNCT []
# All predet money NOUN DET []
# the det money NOUN DET []
# money nsubj went VERB NOUN [All, the]
# went ccomp went VERB VERB [money, into]
# into prep went VERB ADP [decoration]
# the det decoration NOUN DET []
# interior amod decoration NOUN ADJ []
# decoration pobj into ADP NOUN [the, interior]
# , punct went VERB PUNCT []
# none nsubj went VERB NOUN [of]
# of prep none NOUN ADP [it]
# it pobj of ADP PRON []
# went ROOT went VERB VERB [went, ,, none, to, .]
# to prep went VERB ADP [chefs]
# the det chefs NOUN DET []
# chefs pobj to ADP NOUN [the]
# . punct went VERB PUNCT []
# The det seats NOUN DET []
# seats nsubj are AUX NOUN [The]
# are ROOT are AUX AUX [seats, uncomfortable, sitting, .]
# uncomfortable acomp are AUX ADJ []
# if mark sitting VERB SCONJ []
# you nsubj sitting VERB PRON []
# are aux sitting VERB AUX []
# sitting advcl are AUX VERB [if, you, are, against, on]
# against prep sitting VERB ADP [wall]
# the det wall NOUN DET []
# wall pobj against ADP NOUN [the]
# on prep sitting VERB ADP [benches]
# wooden amod benches NOUN ADJ []
# benches pobj on ADP NOUN [wooden]
# . punct are AUX PUNCT []
# I nsubj asked VERB PRON []
# asked ROOT asked VERB VERB [I, for, with, .]
# for prep asked VERB ADP [seltzer]
# seltzer pobj for ADP NOUN []
# with prep asked VERB ADP [lime]
# lime pobj with ADP NOUN [,, ice]
# , punct lime NOUN PUNCT []
# no det ice NOUN DET []
# ice appos lime NOUN NOUN [no]
# . punct asked VERB PUNCT []
# Do aux go VERB AUX []
# n't neg go VERB PART []
# go ccomp is AUX VERB [Do, n't, alone]
# alone advmod go VERB ADV []
# --- punct is AUX PUNCT []
# even advmod two NUM ADV []
# two nummod people NOUN NUM [even]
# people nsubj is AUX NOUN [two]
# is ROOT is AUX AUX [go, ---, people, n't, enough, ,, with, .]
# n't neg is AUX PART []
# enough acomp is AUX ADJ [for]
# for prep enough ADJ ADP [experience]
# the det experience NOUN DET []
# whole amod experience NOUN ADJ []
# experience pobj for ADP NOUN [the, whole]
# , punct is AUX PUNCT []
# with prep is AUX ADP [pickles]
# pickles pobj with ADP NOUN [and, selection]
# and cc pickles NOUN CCONJ []
# a det selection NOUN DET []
# selection conj pickles NOUN NOUN [a, of]
# of prep selection NOUN ADP [meats]
# meats pobj of ADP NOUN [and, seafoods]
# and cc meats NOUN CCONJ []
# seafoods conj meats NOUN NOUN []
# . punct is AUX PUNCT []
# Do aux go VERB AUX []
# n't neg go VERB PART []
# go ccomp is AUX VERB [Do, n't, alone]
# alone advmod go VERB ADV []
# --- punct is AUX PUNCT []
# even advmod two NUM ADV []
# two nummod people NOUN NUM [even]
# people nsubj is AUX NOUN [two]
# is ROOT is AUX AUX [go, ---, people, n't, enough, ,, with, .]
# n't neg is AUX PART []
# enough acomp is AUX ADJ [for]
# for prep enough ADJ ADP [experience]
# the det experience NOUN DET []
# whole amod experience NOUN ADJ []
# experience pobj for ADP NOUN [the, whole]
# , punct is AUX PUNCT []
# with prep is AUX ADP [pickles]
# pickles pobj with ADP NOUN [and, selection]
# and cc pickles NOUN CCONJ []
# a det selection NOUN DET []
# selection conj pickles NOUN NOUN [a, of]
# of prep selection NOUN ADP [meats]
# meats pobj of ADP NOUN [and, seafoods]
# and cc meats NOUN CCONJ []
# seafoods conj meats NOUN NOUN []
# . punct is AUX PUNCT []
# My poss suggestion NOUN PRON []
# suggestion nsubj is AUX NOUN [My]
# is ROOT is AUX AUX [suggestion, eat, .]
# to aux eat VERB PART []
# eat xcomp is AUX VERB [to, style, want]
# family compound style NOUN NOUN []
# style dobj eat VERB NOUN [family]
# because mark want VERB SCONJ []
# you nsubj want VERB PRON []
# 'll aux want VERB AUX []
# want advcl eat VERB VERB [because, you, 'll, try]
# to aux try VERB PART []
# try xcomp want VERB VERB [to, dishes]
# the det dishes NOUN DET []
# other amod dishes NOUN ADJ []
# dishes dobj try VERB NOUN [the, other]
# . punct is AUX PUNCT []
# My poss suggestion NOUN PRON []
# suggestion nsubj is AUX NOUN [My]
# is ROOT is AUX AUX [suggestion, eat, .]
# to aux eat VERB PART []
# eat xcomp is AUX VERB [to, style, want]
# family compound style NOUN NOUN []
# style dobj eat VERB NOUN [family]
# because mark want VERB SCONJ []
# you nsubj want VERB PRON []
# 'll aux want VERB AUX []
# want advcl eat VERB VERB [because, you, 'll, try]
# to aux try VERB PART []
# try xcomp want VERB VERB [to, dishes]
# the det dishes NOUN DET []
# other amod dishes NOUN ADJ []
# dishes dobj try VERB NOUN [the, other]
# . punct is AUX PUNCT []
# Best nsubj is AUX ADJ [of]
# of prep Best ADJ ADP [all]
# all pobj of ADP PRON []
# is ccomp is AUX AUX [Best, vibe]
# the det vibe NOUN DET []
# warm amod vibe NOUN ADJ []
# vibe attr is AUX NOUN [the, warm]
# , punct is AUX PUNCT []
# the det owner NOUN DET []
# owner nsubj is AUX NOUN [the]
# is ROOT is AUX AUX [is, ,, owner, friendly, is]
# super advmod friendly ADJ ADV []
# friendly acomp is AUX ADJ [super, and]
# and cc friendly ADJ CCONJ []
# service nsubj is AUX NOUN []
# is conj is AUX AUX [service, fast, .]
# fast acomp is AUX ADJ []
# . punct is AUX PUNCT []
# Best nsubj is AUX ADJ [of]
# of prep Best ADJ ADP [all]
# all pobj of ADP PRON []
# is ccomp is AUX AUX [Best, vibe]
# the det vibe NOUN DET []
# warm amod vibe NOUN ADJ []
# vibe attr is AUX NOUN [the, warm]
# , punct is AUX PUNCT []
# the det owner NOUN DET []
# owner nsubj is AUX NOUN [the]
# is ROOT is AUX AUX [is, ,, owner, friendly, is]
# super advmod friendly ADJ ADV []
# friendly acomp is AUX ADJ [super, and]
# and cc friendly ADJ CCONJ []
# service nsubj is AUX NOUN []
# is conj is AUX AUX [service, fast, .]
# fast acomp is AUX ADJ []
# . punct is AUX PUNCT []
# Best nsubj is AUX ADJ [of]
# of prep Best ADJ ADP [all]
# all pobj of ADP PRON []
# is ccomp is AUX AUX [Best, vibe]
# the det vibe NOUN DET []
# warm amod vibe NOUN ADJ []
# vibe attr is AUX NOUN [the, warm]
# , punct is AUX PUNCT []
# the det owner NOUN DET []
# owner nsubj is AUX NOUN [the]
# is ROOT is AUX AUX [is, ,, owner, friendly, is]
# super advmod friendly ADJ ADV []
# friendly acomp is AUX ADJ [super, and]
# and cc friendly ADJ CCONJ []
# service nsubj is AUX NOUN []
# is conj is AUX AUX [service, fast, .]
# fast acomp is AUX ADJ []
# . punct is AUX PUNCT []
# Faan nsubj got VERB PROPN ['s]
# 's case Faan PROPN PART []
# got ROOT got VERB VERB [Faan, concept, .]
# a det concept NOUN DET []
# great amod concept NOUN ADJ []
# concept dobj got VERB NOUN [a, great, but, rough]
# but cc concept NOUN CCONJ []
# a det little ADJ DET []
# little npadvmod rough ADJ ADJ [a]
# rough conj concept NOUN ADJ [little, on]
# on prep rough ADJ ADP [delivery]
# the det delivery NOUN DET []
# delivery pobj on ADP NOUN [the]
# . punct got VERB PUNCT []
# From prep miss VERB ADP [food]
# the det food NOUN DET []
# incredible amod food NOUN ADJ []
# food pobj From ADP NOUN [the, incredible]
# , punct miss VERB PUNCT [to]
# to meta , PUNCT ADP [atmosphere, ,]
# the det atmosphere NOUN DET []
# warm amod atmosphere NOUN ADJ []
# atmosphere pobj to ADP NOUN [the, warm]
# , punct to ADP PUNCT []
# to prep miss VERB ADP [service]
# the det service NOUN DET []
# friendly amod service NOUN ADJ []
# service pobj to ADP NOUN [the, friendly]
# , punct miss VERB PUNCT []
# this det spot NOUN DET []
# downtown compound spot NOUN NOUN []
# neighborhood compound spot NOUN NOUN []
# spot nsubj miss VERB NOUN [this, downtown, neighborhood]
# does aux miss VERB AUX []
# n't neg miss VERB PART []
# miss ROOT miss VERB VERB [From, ,, to, ,, spot, does, n't, beat, .]
# a det beat NOUN DET []
# beat dobj miss VERB NOUN [a]
# . punct miss VERB PUNCT []
# From prep miss VERB ADP [food]
# the det food NOUN DET []
# incredible amod food NOUN ADJ []
# food pobj From ADP NOUN [the, incredible]
# , punct miss VERB PUNCT [to]
# to meta , PUNCT ADP [atmosphere, ,]
# the det atmosphere NOUN DET []
# warm amod atmosphere NOUN ADJ []
# atmosphere pobj to ADP NOUN [the, warm]
# , punct to ADP PUNCT []
# to prep miss VERB ADP [service]
# the det service NOUN DET []
# friendly amod service NOUN ADJ []
# service pobj to ADP NOUN [the, friendly]
# , punct miss VERB PUNCT []
# this det spot NOUN DET []
# downtown compound spot NOUN NOUN []
# neighborhood compound spot NOUN NOUN []
# spot nsubj miss VERB NOUN [this, downtown, neighborhood]
# does aux miss VERB AUX []
# n't neg miss VERB PART []
# miss ROOT miss VERB VERB [From, ,, to, ,, spot, does, n't, beat, .]
# a det beat NOUN DET []
# beat dobj miss VERB NOUN [a]
# . punct miss VERB PUNCT []
# From prep miss VERB ADP [food]
# the det food NOUN DET []
# incredible amod food NOUN ADJ []
# food pobj From ADP NOUN [the, incredible]
# , punct miss VERB PUNCT [to]
# to meta , PUNCT ADP [atmosphere, ,]
# the det atmosphere NOUN DET []
# warm amod atmosphere NOUN ADJ []
# atmosphere pobj to ADP NOUN [the, warm]
# , punct to ADP PUNCT []
# to prep miss VERB ADP [service]
# the det service NOUN DET []
# friendly amod service NOUN ADJ []
# service pobj to ADP NOUN [the, friendly]
# , punct miss VERB PUNCT []
# this det spot NOUN DET []
# downtown compound spot NOUN NOUN []
# neighborhood compound spot NOUN NOUN []
# spot nsubj miss VERB NOUN [this, downtown, neighborhood]
# does aux miss VERB AUX []
# n't neg miss VERB PART []
# miss ROOT miss VERB VERB [From, ,, to, ,, spot, does, n't, beat, .]
# a det beat NOUN DET []
# beat dobj miss VERB NOUN [a]
# . punct miss VERB PUNCT []
# Great amod food NOUN ADJ []
# food nsubj makes VERB NOUN [Great, at, ,]
# at prep food NOUN ADP [prices]
# REASONABLE amod prices NOUN ADJ []
# prices pobj at ADP NOUN [REASONABLE]
# , punct food NOUN PUNCT []
# makes ROOT makes VERB VERB [food, for, !]
# for prep makes VERB ADP [evening]
# an det evening NOUN DET []
# evening pobj for ADP NOUN [an, beat]
# that nsubjpass beat VERB PRON []
# ca aux beat VERB AUX []
# n't neg beat VERB PART []
# be auxpass beat VERB AUX []
# beat relcl evening NOUN VERB [that, ca, n't, be]
# ! punct makes VERB PUNCT []
# Great amod food NOUN ADJ []
# food nsubj makes VERB NOUN [Great, at, ,]
# at prep food NOUN ADP [prices]
# REASONABLE amod prices NOUN ADJ []
# prices pobj at ADP NOUN [REASONABLE]
# , punct food NOUN PUNCT []
# makes ROOT makes VERB VERB [food, for, !]
# for prep makes VERB ADP [evening]
# an det evening NOUN DET []
# evening pobj for ADP NOUN [an, beat]
# that nsubjpass beat VERB PRON []
# ca aux beat VERB AUX []
# n't neg beat VERB PART []
# be auxpass beat VERB AUX []
# beat relcl evening NOUN VERB [that, ca, n't, be]
# ! punct makes VERB PUNCT []
# this det place NOUN DET []
# little amod place NOUN ADJ []
# place nsubj has VERB NOUN [this, little]
# has ROOT has VERB VERB [place, prices, .]
# a det prices NOUN DET []
# cute amod prices NOUN ADJ []
# interior amod decor NOUN ADJ []
# decor nmod prices NOUN NOUN [interior, and, city]
# and cc decor NOUN CCONJ []
# affordable amod city NOUN ADJ []
# city conj decor NOUN NOUN [affordable]
# prices dobj has VERB NOUN [a, cute, decor]
# . punct has VERB PUNCT []
# this det place NOUN DET []
# little amod place NOUN ADJ []
# place nsubj has VERB NOUN [this, little]
# has ROOT has VERB VERB [place, prices, .]
# a det prices NOUN DET []
# cute amod prices NOUN ADJ []
# interior amod decor NOUN ADJ []
# decor nmod prices NOUN NOUN [interior, and, city]
# and cc decor NOUN CCONJ []
# affordable amod city NOUN ADJ []
# city conj decor NOUN NOUN [affordable]
# prices dobj has VERB NOUN [a, cute, decor]
# . punct has VERB PUNCT []
# Two nummod words NOUN NUM []
# words ROOT words NOUN NOUN [Two, :, wine, .]
# : punct words NOUN PUNCT []
# Free amod wine NOUN ADJ []
# wine appos words NOUN NOUN [Free]
# . punct words NOUN PUNCT []
# The det price NOUN DET []
# price nsubj is AUX NOUN [The]
# is ROOT is AUX AUX [price, reasonable, is, .]
# reasonable acomp is AUX ADJ []
# although mark is AUX SCONJ []
# the det service NOUN DET []
# service nsubj is AUX NOUN [the]
# is advcl is AUX AUX [although, service, poor]
# poor acomp is AUX ADJ []
# . punct is AUX PUNCT []
# The det price NOUN DET []
# price nsubj is AUX NOUN [The]
# is ROOT is AUX AUX [price, reasonable, is, .]
# reasonable acomp is AUX ADJ []
# although mark is AUX SCONJ []
# the det service NOUN DET []
# service nsubj is AUX NOUN [the]
# is advcl is AUX AUX [although, service, poor]
# poor acomp is AUX ADJ []
# . punct is AUX PUNCT []
# The det quantity NOUN DET []
# quantity nsubj is AUX NOUN [The]
# is ccomp come VERB AUX [quantity, also, good]
# also advmod is AUX ADV []
# very advmod good ADJ ADV []
# good acomp is AUX ADJ [very]
# , punct come VERB PUNCT []
# you nsubj come VERB PRON []
# will aux come VERB AUX []
# come ROOT come VERB VERB [is, ,, you, will, out, satisfied, .]
# out prt come VERB ADP []
# satisfied advcl come VERB ADJ []
# . punct come VERB PUNCT []
# I nsubj stumbled VERB PRON []
# stumbled ROOT stumbled VERB VERB [I, upon, ago, sat]
# upon prep stumbled VERB SCONJ [floor]
# this det floor NOUN DET []
# second amod floor NOUN ADJ []
# floor pobj upon SCONJ NOUN [this, second, walk]
# walk appos floor NOUN VERB [-, up]
# - punct walk VERB PUNCT []
# up prt walk VERB ADP []
# two nummod Fridays PROPN NUM []
# Fridays npadvmod ago ADV PROPN [two]
# ago advmod stumbled VERB ADV [Fridays]
# when advmod was AUX SCONJ []
# I nsubj was AUX PRON []
# was advcl sat VERB AUX [when, I, with, from]
# with prep was AUX ADP [friends]
# two nummod friends NOUN NUM []
# friends pobj with ADP NOUN [two, in]
# in prep friends NOUN ADP [town]
# town pobj in ADP NOUN []
# from prep was AUX ADP [L.A., Being]
# L.A. pobj from ADP PROPN []
# Being pcomp from ADP AUX [lovers]
# serious amod lovers NOUN ADJ []
# sushi amod lovers NOUN ADJ []
# lovers attr Being AUX NOUN [serious, sushi]
# , punct sat VERB PUNCT []
# we nsubj sat VERB PRON []
# sat ccomp stumbled VERB VERB [was, ,, we, at, be, .]
# at prep sat VERB ADP [bar]
# the det bar NOUN DET []
# sushi compound bar NOUN PROPN []
# bar pobj at ADP NOUN [the, sushi]
# to aux be AUX PART []
# be advcl sat VERB AUX [to, closer]
# closer acomp be AUX ADJ [to]
# to prep closer ADJ ADP [action]
# the det action NOUN DET []
# action pobj to ADP NOUN [the]
# . punct sat VERB PUNCT []
# I nsubj stumbled VERB PRON []
# stumbled ROOT stumbled VERB VERB [I, upon, ago, sat]
# upon prep stumbled VERB SCONJ [floor]
# this det floor NOUN DET []
# second amod floor NOUN ADJ []
# floor pobj upon SCONJ NOUN [this, second, walk]
# walk appos floor NOUN VERB [-, up]
# - punct walk VERB PUNCT []
# up prt walk VERB ADP []
# two nummod Fridays PROPN NUM []
# Fridays npadvmod ago ADV PROPN [two]
# ago advmod stumbled VERB ADV [Fridays]
# when advmod was AUX SCONJ []
# I nsubj was AUX PRON []
# was advcl sat VERB AUX [when, I, with, from]
# with prep was AUX ADP [friends]
# two nummod friends NOUN NUM []
# friends pobj with ADP NOUN [two, in]
# in prep friends NOUN ADP [town]
# town pobj in ADP NOUN []
# from prep was AUX ADP [L.A., Being]
# L.A. pobj from ADP PROPN []
# Being pcomp from ADP AUX [lovers]
# serious amod lovers NOUN ADJ []
# sushi amod lovers NOUN ADJ []
# lovers attr Being AUX NOUN [serious, sushi]
# , punct sat VERB PUNCT []
# we nsubj sat VERB PRON []
# sat ccomp stumbled VERB VERB [was, ,, we, at, be, .]
# at prep sat VERB ADP [bar]
# the det bar NOUN DET []
# sushi compound bar NOUN PROPN []
# bar pobj at ADP NOUN [the, sushi]
# to aux be AUX PART []
# be advcl sat VERB AUX [to, closer]
# closer acomp be AUX ADJ [to]
# to prep closer ADJ ADP [action]
# the det action NOUN DET []
# action pobj to ADP NOUN [the]
# . punct sat VERB PUNCT []
# The det rice NOUN DET []
# fried amod rice NOUN ADJ []
# rice nsubj is AUX NOUN [The, fried]
# is ROOT is AUX AUX [rice, amazing, here, .]
# amazing acomp is AUX ADJ []
# here advmod is AUX ADV []
# . punct is AUX PUNCT []
# Three nummod courses NOUN NUM []
# courses compound choices NOUN NOUN [Three]
# - punct choices NOUN PUNCT []
# choices nsubj include VERB NOUN [courses, -]
# include ROOT include VERB VERB [choices, mussels, and, salad, ,, and, steak, .]
# excellent amod mussels NOUN ADJ []
# mussels dobj include VERB NOUN [excellent, ,, cheese]
# , punct mussels NOUN PUNCT []
# puff compound pastry NOUN PROPN []
# pastry compound cheese NOUN NOUN [puff]
# goat compound cheese NOUN NOUN []
# cheese appos mussels NOUN NOUN [pastry, goat]
# and cc include VERB CCONJ []
# salad conj include VERB VERB [with]
# with prep salad VERB ADP [dressing]
# a det dressing NOUN DET []
# delicious amod dressing NOUN ADJ []
# dressing pobj with ADP NOUN [a, delicious]
# , punct include VERB PUNCT []
# and cc include VERB CCONJ []
# a det steak NOUN DET []
# hanger amod steak NOUN ADJ []
# steak conj include VERB NOUN [a, hanger, poivre]
# au nmod poivre NOUN ADP []
# poivre appos steak NOUN NOUN [au, is]
# that nsubj is AUX PRON []
# is relcl poivre NOUN AUX [that, out]
# out prep is AUX ADP [of]
# of prep out ADP ADP [world]
# this det world NOUN DET []
# world pobj of ADP NOUN [this]
# . punct include VERB PUNCT []
# Three nummod courses NOUN NUM []
# courses compound choices NOUN NOUN [Three]
# - punct choices NOUN PUNCT []
# choices nsubj include VERB NOUN [courses, -]
# include ROOT include VERB VERB [choices, mussels, and, salad, ,, and, steak, .]
# excellent amod mussels NOUN ADJ []
# mussels dobj include VERB NOUN [excellent, ,, cheese]
# , punct mussels NOUN PUNCT []
# puff compound pastry NOUN PROPN []
# pastry compound cheese NOUN NOUN [puff]
# goat compound cheese NOUN NOUN []
# cheese appos mussels NOUN NOUN [pastry, goat]
# and cc include VERB CCONJ []
# salad conj include VERB VERB [with]
# with prep salad VERB ADP [dressing]
# a det dressing NOUN DET []
# delicious amod dressing NOUN ADJ []
# dressing pobj with ADP NOUN [a, delicious]
# , punct include VERB PUNCT []
# and cc include VERB CCONJ []
# a det steak NOUN DET []
# hanger amod steak NOUN ADJ []
# steak conj include VERB NOUN [a, hanger, poivre]
# au nmod poivre NOUN ADP []
# poivre appos steak NOUN NOUN [au, is]
# that nsubj is AUX PRON []
# is relcl poivre NOUN AUX [that, out]
# out prep is AUX ADP [of]
# of prep out ADP ADP [world]
# this det world NOUN DET []
# world pobj of ADP NOUN [this]
# . punct include VERB PUNCT []
# Three nummod courses NOUN NUM []
# courses compound choices NOUN NOUN [Three]
# - punct choices NOUN PUNCT []
# choices nsubj include VERB NOUN [courses, -]
# include ROOT include VERB VERB [choices, mussels, and, salad, ,, and, steak, .]
# excellent amod mussels NOUN ADJ []
# mussels dobj include VERB NOUN [excellent, ,, cheese]
# , punct mussels NOUN PUNCT []
# puff compound pastry NOUN PROPN []
# pastry compound cheese NOUN NOUN [puff]
# goat compound cheese NOUN NOUN []
# cheese appos mussels NOUN NOUN [pastry, goat]
# and cc include VERB CCONJ []
# salad conj include VERB VERB [with]
# with prep salad VERB ADP [dressing]
# a det dressing NOUN DET []
# delicious amod dressing NOUN ADJ []
# dressing pobj with ADP NOUN [a, delicious]
# , punct include VERB PUNCT []
# and cc include VERB CCONJ []
# a det steak NOUN DET []
# hanger amod steak NOUN ADJ []
# steak conj include VERB NOUN [a, hanger, poivre]
# au nmod poivre NOUN ADP []
# poivre appos steak NOUN NOUN [au, is]
# that nsubj is AUX PRON []
# is relcl poivre NOUN AUX [that, out]
# out prep is AUX ADP [of]
# of prep out ADP ADP [world]
# this det world NOUN DET []
# world pobj of ADP NOUN [this]
# . punct include VERB PUNCT []
# Three nummod courses NOUN NUM []
# courses compound choices NOUN NOUN [Three]
# - punct choices NOUN PUNCT []
# choices nsubj include VERB NOUN [courses, -]
# include ROOT include VERB VERB [choices, mussels, and, salad, ,, and, steak, .]
# excellent amod mussels NOUN ADJ []
# mussels dobj include VERB NOUN [excellent, ,, cheese]
# , punct mussels NOUN PUNCT []
# puff compound pastry NOUN PROPN []
# pastry compound cheese NOUN NOUN [puff]
# goat compound cheese NOUN NOUN []
# cheese appos mussels NOUN NOUN [pastry, goat]
# and cc include VERB CCONJ []
# salad conj include VERB VERB [with]
# with prep salad VERB ADP [dressing]
# a det dressing NOUN DET []
# delicious amod dressing NOUN ADJ []
# dressing pobj with ADP NOUN [a, delicious]
# , punct include VERB PUNCT []
# and cc include VERB CCONJ []
# a det steak NOUN DET []
# hanger amod steak NOUN ADJ []
# steak conj include VERB NOUN [a, hanger, poivre]
# au nmod poivre NOUN ADP []
# poivre appos steak NOUN NOUN [au, is]
# that nsubj is AUX PRON []
# is relcl poivre NOUN AUX [that, out]
# out prep is AUX ADP [of]
# of prep out ADP ADP [world]
# this det world NOUN DET []
# world pobj of ADP NOUN [this]
# . punct include VERB PUNCT []
# Three nummod courses NOUN NUM []
# courses compound choices NOUN NOUN [Three]
# - punct choices NOUN PUNCT []
# choices nsubj include VERB NOUN [courses, -]
# include ROOT include VERB VERB [choices, mussels, and, salad, ,, and, steak, .]
# excellent amod mussels NOUN ADJ []
# mussels dobj include VERB NOUN [excellent, ,, cheese]
# , punct mussels NOUN PUNCT []
# puff compound pastry NOUN PROPN []
# pastry compound cheese NOUN NOUN [puff]
# goat compound cheese NOUN NOUN []
# cheese appos mussels NOUN NOUN [pastry, goat]
# and cc include VERB CCONJ []
# salad conj include VERB VERB [with]
# with prep salad VERB ADP [dressing]
# a det dressing NOUN DET []
# delicious amod dressing NOUN ADJ []
# dressing pobj with ADP NOUN [a, delicious]
# , punct include VERB PUNCT []
# and cc include VERB CCONJ []
# a det steak NOUN DET []
# hanger amod steak NOUN ADJ []
# steak conj include VERB NOUN [a, hanger, poivre]
# au nmod poivre NOUN ADP []
# poivre appos steak NOUN NOUN [au, is]
# that nsubj is AUX PRON []
# is relcl poivre NOUN AUX [that, out]
# out prep is AUX ADP [of]
# of prep out ADP ADP [world]
# this det world NOUN DET []
# world pobj of ADP NOUN [this]
# . punct include VERB PUNCT []
# it nsubj 's AUX PRON []
# 's ROOT 's AUX AUX [it, place, .]
# a det place NOUN DET []
# perfect amod place NOUN ADJ []
# place attr 's AUX NOUN [a, perfect, have]
# to aux have VERB PART []
# have relcl place NOUN VERB [to, food]
# a det food NOUN DET []
# amanzing amod food NOUN VERB []
# indian amod food NOUN ADJ []
# food dobj have VERB NOUN [a, amanzing, indian]
# . punct 's AUX PUNCT []
# The det place NOUN DET []
# place nsubj is AUX NOUN [The]
# is ROOT is AUX AUX [place, cool, and, is]
# so advmod cool ADJ ADV []
# cool acomp is AUX ADJ [so]
# and cc is AUX CCONJ []
# the det service NOUN DET []
# service nsubj is AUX NOUN [the]
# is conj is AUX AUX [service, prompt, .]
# prompt acomp is AUX ADJ [and, curtious]
# and cc prompt ADJ CCONJ []
# curtious conj prompt ADJ ADJ []
# . punct is AUX PUNCT []
# The det place NOUN DET []
# place nsubj is AUX NOUN [The]
# is ROOT is AUX AUX [place, cool, and, is]
# so advmod cool ADJ ADV []
# cool acomp is AUX ADJ [so]
# and cc is AUX CCONJ []
# the det service NOUN DET []
# service nsubj is AUX NOUN [the]
# is conj is AUX AUX [service, prompt, .]
# prompt acomp is AUX ADJ [and, curtious]
# and cc prompt ADJ CCONJ []
# curtious conj prompt ADJ ADJ []
# . punct is AUX PUNCT []
# At prep left VERB ADP [end]
# the det end NOUN DET []
# end pobj At ADP NOUN [the]
# you nsubjpass left VERB PRON []
# 're auxpass left VERB AUX []
# left ROOT left VERB VERB [At, you, 're, with, slurp, .]
# with prep left VERB ADP [broth]
# a det broth NOUN DET []
# mild amod broth NOUN ADJ []
# broth pobj with ADP NOUN [a, mild, with]
# with prep broth NOUN ADP [noodles]
# noodles pobj with ADP NOUN []
# that dobj slurp VERB SCONJ []
# you nsubj slurp VERB PRON []
# can aux slurp VERB AUX []
# slurp ccomp left VERB VERB [that, you, can, out]
# out prep slurp VERB ADP [of]
# of prep out ADP ADP [cup]
# a det cup NOUN DET []
# cup pobj of ADP NOUN [a]
# . punct left VERB PUNCT []
# I nsubj wonder VERB PRON []
# just advmod wonder VERB ADV []
# wonder ROOT wonder VERB VERB [I, just, have, .]
# how advmod have VERB SCONJ []
# you nsubj have VERB PRON []
# can aux have VERB AUX []
# have ccomp wonder VERB VERB [how, you, can, meal]
# such predet meal NOUN DET []
# a det meal NOUN DET []
# delicious amod meal NOUN ADJ []
# meal dobj have VERB NOUN [such, a, delicious, for]
# for prep meal NOUN ADP [money]
# such amod money NOUN ADJ []
# little amod money NOUN ADJ []
# money pobj for ADP NOUN [such, little]
# . punct wonder VERB PUNCT []
# I nsubj wonder VERB PRON []
# just advmod wonder VERB ADV []
# wonder ROOT wonder VERB VERB [I, just, have, .]
# how advmod have VERB SCONJ []
# you nsubj have VERB PRON []
# can aux have VERB AUX []
# have ccomp wonder VERB VERB [how, you, can, meal]
# such predet meal NOUN DET []
# a det meal NOUN DET []
# delicious amod meal NOUN ADJ []
# meal dobj have VERB NOUN [such, a, delicious, for]
# for prep meal NOUN ADP [money]
# such amod money NOUN ADJ []
# little amod money NOUN ADJ []
# money pobj for ADP NOUN [such, little]
# . punct wonder VERB PUNCT []
# The det food NOUN DET []
# food nsubj was AUX NOUN [The]
# was ROOT was AUX AUX [food, delicious, but, come, .]
# delicious acomp was AUX ADJ []
# but cc was AUX CCONJ []
# do aux come VERB AUX []
# not neg come VERB PART []
# come conj was AUX VERB [do, not, here, on]
# here advmod come VERB ADV []
# on prep come VERB ADP [stomach]
# a det stomach NOUN DET []
# ...
# to aux hang VERB PART []
# hang relcl place NOUN VERB [to, out, in]
# out prt hang VERB ADP []
# in prep hang VERB ADP []
# . punct spreads NOUN PUNCT []
# Great amod bagels NOUN ADJ []
# bagels nsubj spreads NOUN NOUN [Great, ,]
# , punct bagels NOUN PUNCT []
# spreads ROOT spreads NOUN NOUN [bagels, and, place, .]
# and cc spreads NOUN CCONJ []
# a det place NOUN DET []
# good amod place NOUN ADJ []
# place conj spreads NOUN NOUN [a, good, hang]
# to aux hang VERB PART []
# hang relcl place NOUN VERB [to, out, in]
# out prt hang VERB ADP []
# in prep hang VERB ADP []
# . punct spreads NOUN PUNCT []
# The det varys NOUN DET []
# service compound varys NOUN NOUN []
# varys nsubj 're AUX NOUN [The, service, from, to]
# from prep varys NOUN ADP [day]
# day pobj from ADP NOUN []
# to prep varys NOUN ADP [day-]
# day- pobj to ADP NOUN []
# sometimes advmod 're AUX ADV []
# they nsubj 're AUX PRON []
# 're ROOT 're AUX AUX [varys, sometimes, they, nice, ,, and, not, .]
# very advmod nice ADJ ADV []
# nice acomp 're AUX ADJ [very]
# , punct 're AUX PUNCT []
# and cc 're AUX CCONJ []
# sometimes advmod not PART ADV []
# not conj 're AUX PART [sometimes]
# . punct 're AUX PUNCT []
# One nummod thing NOUN NUM []
# thing nsubj is AUX NOUN [One, liked]
# I nsubj liked VERB PRON []
# liked relcl thing NOUN VERB [I, about]
# about prep liked VERB ADP [place]
# this det place NOUN DET []
# place pobj about ADP NOUN [this]
# is ROOT is AUX AUX [thing, rushed, .]
# that mark rushed VERB SCONJ []
# I nsubj felt AUX PRON []
# never neg felt AUX ADV []
# felt aux rushed VERB AUX [I, never]
# rushed ccomp is AUX VERB [that, felt, or, pressured]
# or cc rushed VERB CCONJ []
# pressured conj rushed VERB VERB [give]
# to aux give VERB PART []
# give xcomp pressured VERB VERB [to, up, table, guests]
# up prt give VERB ADP []
# my poss table NOUN PRON []
# table dobj give VERB NOUN [my]
# ot nmod guests NOUN NOUN []
# incoming amod guests NOUN ADJ []
# guests dobj give VERB NOUN [ot, incoming]
# . punct is AUX PUNCT []
# Unfortunately advmod is AUX ADV []
# , punct is AUX PUNCT []
# the det food NOUN DET []
# food nsubj is AUX NOUN [the]
# is ROOT is AUX AUX [Unfortunately, ,, food, outstanding, ,, but, is]
# outstanding acomp is AUX ADJ []
# , punct is AUX PUNCT []
# but cc is AUX CCONJ []
# everything nsubj is AUX PRON [else, about]
# else advmod everything PRON ADV []
# about prep everything PRON ADP [restaurant]
# this det restaurant NOUN DET []
# restaurant pobj about ADP NOUN [this]
# is conj is AUX AUX [everything, pits, .]
# the det pits NOUN DET []
# pits attr is AUX NOUN [the]
# . punct is AUX PUNCT []
# We nsubj have VERB PRON []
# always advmod have VERB ADV []
# have ROOT have VERB VERB [We, always, meal, and, leave, .]
# a det meal NOUN DET []
# delicious amod meal NOUN ADJ []
# meal dobj have VERB NOUN [a, delicious]
# and cc have VERB CCONJ []
# always advmod leave VERB ADV []
# leave conj have VERB VERB [always, feeling]
# feeling dobj leave VERB VERB [satisfied]
# satisfied acomp feeling VERB ADJ []
# . punct have VERB PUNCT []
# Dip advmod swirl VERB ADV []
# the det ingredients NOUN DET []
# ingredients nsubj swirl VERB NOUN [the, in, with]
# in prep ingredients NOUN ADP []
# with prep ingredients NOUN ADP [chopsticks]
# your poss chopsticks NOUN PRON []
# chopsticks pobj with ADP NOUN [your]
# , punct swirl VERB PUNCT []
# swirl ROOT swirl VERB VERB [Dip, ingredients, ,, them, around, ,, and, eat, .]
# them dobj swirl VERB PRON []
# around advmod swirl VERB ADV []
# , punct swirl VERB PUNCT []
# and cc swirl VERB CCONJ []
# eat conj swirl VERB VERB []
# . punct swirl VERB PUNCT []
# Dip advmod swirl VERB ADV []
# the det ingredients NOUN DET []
# ingredients nsubj swirl VERB NOUN [the, in, with]
# in prep ingredients NOUN ADP []
# with prep ingredients NOUN ADP [chopsticks]
# your poss chopsticks NOUN PRON []
# chopsticks pobj with ADP NOUN [your]
# , punct swirl VERB PUNCT []
# swirl ROOT swirl VERB VERB [Dip, ingredients, ,, them, around, ,, and, eat, .]
# them dobj swirl VERB PRON []
# around advmod swirl VERB ADV []
# , punct swirl VERB PUNCT []
# and cc swirl VERB CCONJ []
# eat conj swirl VERB VERB []
# . punct swirl VERB PUNCT []
# First advmod went VERB ADV []
# went ROOT went VERB VERB [First, here, enjoy, .]
# here advmod went VERB ADV []
# to aux enjoy VERB PART []
# enjoy advcl went VERB VERB [to, terrace]
# their poss terrace NOUN PRON []
# garden compound terrace NOUN NOUN []
# terrace dobj enjoy VERB NOUN [their, garden]
# . punct went VERB PUNCT []
# The det pizza NOUN DET []
# pizza nsubj was AUX NOUN [The]
# was ROOT was AUX AUX [pizza, good, .]
# pretty advmod good ADJ ADV []
# good acomp was AUX ADJ [pretty, and, huge]
# and cc good ADJ CCONJ []
# huge conj good ADJ ADJ []
# . punct was AUX PUNCT []
# The det cuisine NOUN DET []
# cuisine nsubj is AUX NOUN [The, from]
# from prep cuisine NOUN ADP [gathered]
# what dobj gathered VERB PRON []
# I nsubj gathered VERB PRON []
# 've aux gathered VERB AUX []
# gathered pcomp from ADP VERB [what, I, 've]
# is ROOT is AUX AUX [cuisine, Taiwanese, ,, different, .]
# authentic amod Taiwanese PROPN ADJ []
# Taiwanese attr is AUX PROPN [authentic]
# , punct is AUX PUNCT []
# though mark different ADJ SCONJ []
# its poss different ADJ PRON []
# very advmod different ADJ ADV []
# different advcl is AUX ADJ [though, its, very, from]
# from prep different ADJ ADP [accustomed]
# what pobj to ADP PRON []
# I nsubjpass accustomed VERB PRON []
# 've aux accustomed VERB AUX []
# been auxpass accustomed VERB AUX []
# accustomed pcomp from ADP VERB [I, 've, been, to]
# to prep accustomed VERB ADP [what, in]
# in prep to ADP ADP [Taipei]
# Taipei pobj in ADP PROPN []
# . punct is AUX PUNCT []
# I nsubj hesititate VERB PRON []
# almost advmod hesititate VERB ADV []
# hesititate ROOT hesititate VERB VERB [I, almost, write, .]
# to aux write VERB PART []
# write xcomp hesititate VERB VERB [to, review, was]
# a det review NOUN DET []
# review dobj write VERB NOUN [a]
# because mark was AUX SCONJ []
# the det atmosphere NOUN DET []
# atmosphere nsubj was AUX NOUN [the]
# was advcl write VERB AUX [because, atmosphere, great, and, hate]
# so advmod great ADJ ADV []
# great acomp was AUX ADJ [so]
# and cc was AUX CCONJ []
# I nsubj hate VERB PRON []
# would aux hate VERB AUX []
# hate conj was AUX VERB [I, would, become]
# for mark become VERB SCONJ []
# it nsubj become VERB PRON []
# too advmod become VERB ADV []
# become advcl hate VERB VERB [for, it, too, crowded]
# to aux crowded VERB AUX []
# crowded xcomp become VERB VERB [to]
# . punct hesititate VERB PUNCT []
# They nsubj are AUX PRON []
# are ROOT are AUX AUX [They, often, crowded, but, are]
# often advmod are AUX ADV []
# crowded acomp are AUX VERB [on]
# on prep crowded VERB ADP [weekends]
# the det weekends NOUN DET []
# weekends pobj on ADP NOUN [the]
# but cc are AUX CCONJ []
# they nsubj are AUX PRON []
# are conj are AUX AUX [they, efficient, .]
# efficient acomp are AUX ADJ [and, accurate]
# and cc efficient ADJ CCONJ []
# accurate conj efficient ADJ ADJ [with]
# with prep accurate ADJ ADP [service]
# their poss service NOUN PRON []
# service pobj with ADP NOUN [their]
# . punct are AUX PUNCT []
# They nsubj are AUX PRON []
# are ROOT are AUX AUX [They, often, crowded, but, are]
# often advmod are AUX ADV []
# crowded acomp are AUX VERB [on]
# on prep crowded VERB ADP [weekends]
# the det weekends NOUN DET []
# weekends pobj on ADP NOUN [the]
# but cc are AUX CCONJ []
# they nsubj are AUX PRON []
# are conj are AUX AUX [they, efficient, .]
# efficient acomp are AUX ADJ [and, accurate]
# and cc efficient ADJ CCONJ []
# accurate conj efficient ADJ ADJ [with]
# with prep accurate ADJ ADP [service]
# their poss service NOUN PRON []
# service pobj with ADP NOUN [their]
# . punct are AUX PUNCT []
# All predet co NOUN DET []
# my poss co NOUN PRON []
# co nsubj were AUX NOUN [All, my]
# - nsubj were AUX NOUN []
# workers nsubj were AUX NOUN []
# were ROOT were AUX AUX [co, -, workers, amazed, .]
# amazed acomp were AUX ADJ [at]
# at prep amazed ADJ ADP [was]
# how advmod small ADJ SCONJ []
# small acomp was AUX ADJ [how]
# the det dish NOUN DET []
# dish nsubj was AUX NOUN [the]
# was pcomp at ADP AUX [small, dish]
# . punct were AUX PUNCT []
# The det atmosphere NOUN DET []
# atmosphere nsubj is AUX NOUN [The]
# is ccomp impecible ADJ AUX [atmosphere, unheralded]
# unheralded acomp is AUX ADJ []
# , punct impecible ADJ PUNCT []
# the det service NOUN DET []
# service nsubj impecible ADJ NOUN [the]
# impecible ROOT impecible ADJ ADJ [is, ,, service, ,, and, magnificant, .]
# , punct impecible ADJ PUNCT []
# and cc impecible ADJ CCONJ []
# the det magnificant NOUN DET []
# food compound magnificant NOUN NOUN []
# magnificant conj impecible ADJ NOUN [the, food]
# . punct impecible ADJ PUNCT []
# The det atmosphere NOUN DET []
# atmosphere nsubj is AUX NOUN [The]
# is ccomp impecible ADJ AUX [atmosphere, unheralded]
# unheralded acomp is AUX ADJ []
# , punct impecible ADJ PUNCT []
# the det service NOUN DET []
# service nsubj impecible ADJ NOUN [the]
# impecible ROOT impecible ADJ ADJ [is, ,, service, ,, and, magnificant, .]
# , punct impecible ADJ PUNCT []
# and cc impecible ADJ CCONJ []
# the det magnificant NOUN DET []
# food compound magnificant NOUN NOUN []
# magnificant conj impecible ADJ NOUN [the, food]
# . punct impecible ADJ PUNCT []
# The det atmosphere NOUN DET []
# atmosphere nsubj is AUX NOUN [The]
# is ccomp impecible ADJ AUX [atmosphere, unheralded]
# unheralded acomp is AUX ADJ []
# , punct impecible ADJ PUNCT []
# the det service NOUN DET []
# service nsubj impecible ADJ NOUN [the]
# impecible ROOT impecible ADJ ADJ [is, ,, service, ,, and, magnificant, .]
# , punct impecible ADJ PUNCT []
# and cc impecible ADJ CCONJ []
# the det magnificant NOUN DET []
# food compound magnificant NOUN NOUN []
# magnificant conj impecible ADJ NOUN [the, food]
# . punct impecible ADJ PUNCT []
# We nsubj ordered VERB PRON []
# ordered ROOT ordered VERB VERB [We, branzino, was, was, .]
# the det branzino NOUN DET []
# special amod branzino NOUN ADJ []
# , punct branzino NOUN PUNCT []
# grilled amod branzino NOUN VERB []
# branzino dobj ordered VERB NOUN [the, special, ,, grilled, ,]
# , punct branzino NOUN PUNCT []
# that nsubj was AUX PRON []
# was ccomp ordered VERB AUX [that, infused]
# so advmod infused VERB ADV []
# infused acomp was AUX VERB [so, with]
# with prep infused VERB ADP [bone]
# bone pobj with ADP NOUN []
# , punct was AUX PUNCT []
# it nsubj was AUX PRON []
# was ccomp ordered VERB AUX [,, it, difficult]
# difficult acomp was AUX ADJ [eat]
# to aux eat VERB PART []
# eat xcomp difficult ADJ VERB [to]
# . punct ordered VERB PUNCT []
# The det staff NOUN DET []
# wait compound staff NOUN NOUN []
# staff nsubj is AUX NOUN [The, wait]
# is ROOT is AUX AUX [staff, friendly, ,, and, gotten]
# friendly acomp is AUX ADJ []
# , punct is AUX PUNCT []
# and cc is AUX CCONJ []
# the det food NOUN DET []
# food nsubj gotten VERB NOUN [the]
# has aux gotten VERB AUX []
# gotten conj is AUX VERB [food, has, better, !]
# better acomp gotten VERB ADJ [and, better]
# and cc better ADJ CCONJ []
# better conj better ADJ ADJ []
# ! punct gotten VERB PUNCT []
# The det staff NOUN DET []
# wait compound staff NOUN NOUN []
# staff nsubj is AUX NOUN [The, wait]
# is ROOT is AUX AUX [staff, friendly, ,, and, gotten]
# friendly acomp is AUX ADJ []
# , punct is AUX PUNCT []
# and cc is AUX CCONJ []
# the det food NOUN DET []
# food nsubj gotten VERB NOUN [the]
# has aux gotten VERB AUX []
# gotten conj is AUX VERB [food, has, better, !]
# better acomp gotten VERB ADJ [and, better]
# and cc better ADJ CCONJ []
# better conj better ADJ ADJ []
# ! punct gotten VERB PUNCT []
# It nsubj be AUX PRON []
# may aux be AUX AUX []
# be ROOT be AUX AUX [It, may, packed, ,, but, is]
# a det bit NOUN DET []
# bit npadvmod packed ADJ NOUN [a]
# packed acomp be AUX ADJ [bit, on]
# on prep packed ADJ ADP [weekends]
# weekends pobj on ADP NOUN []
# , punct be AUX PUNCT []
# but cc be AUX CCONJ []
# the det vibe NOUN DET []
# vibe nsubj is AUX NOUN [the]
# is conj be AUX AUX [vibe, good, and, is, .]
# good acomp is AUX ADJ []
# and cc is AUX CCONJ []
# it nsubj is AUX PRON []
# is conj is AUX AUX [it, food]
# the det food NOUN DET []
# best amod food NOUN ADJ []
# French amod food NOUN ADJ []
# food attr is AUX NOUN [the, best, French, find]
# you nsubj find VERB PRON []
# will aux find VERB AUX []
# find relcl food NOUN VERB [you, will, in]
# in prep find VERB ADP [area]
# the det area NOUN DET []
# area pobj in ADP NOUN [the]
# . punct is AUX PUNCT []
# It nsubj be AUX PRON []
# may aux be AUX AUX []
# be ROOT be AUX AUX [It, may, packed, ,, but, is]
# a det bit NOUN DET []
# bit npadvmod packed ADJ NOUN [a]
# packed acomp be AUX ADJ [bit, on]
# on prep packed ADJ ADP [weekends]
# weekends pobj on ADP NOUN []
# , punct be AUX PUNCT []
# but cc be AUX CCONJ []
# the det vibe NOUN DET []
# vibe nsubj is AUX NOUN [the]
# is conj be AUX AUX [vibe, good, and, is, .]
# good acomp is AUX ADJ []
# and cc is AUX CCONJ []
# it nsubj is AUX PRON []
# is conj is AUX AUX [it, food]
# the det food NOUN DET []
# best amod food NOUN ADJ []
# French amod food NOUN ADJ []
# food attr is AUX NOUN [the, best, French, find]
# you nsubj find VERB PRON []
# will aux find VERB AUX []
# find relcl food NOUN VERB [you, will, in]
# in prep find VERB ADP [area]
# the det area NOUN DET []
# area pobj in ADP NOUN [the]
# . punct is AUX PUNCT []
# It nsubj be AUX PRON []
# may aux be AUX AUX []
# be ROOT be AUX AUX [It, may, packed, ,, but, is]
# a det bit NOUN DET []
# bit npadvmod packed ADJ NOUN [a]
# packed acomp be AUX ADJ [bit, on]
# on prep packed ADJ ADP [weekends]
# weekends pobj on ADP NOUN []
# , punct be AUX PUNCT []
# but cc be AUX CCONJ []
# the det vibe NOUN DET []
# vibe nsubj is AUX NOUN [the]
# is conj be AUX AUX [vibe, good, and, is, .]
# good acomp is AUX ADJ []
# and cc is AUX CCONJ []
# it nsubj is AUX PRON []
# is conj is AUX AUX [it, food]
# the det food NOUN DET []
# best amod food NOUN ADJ []
# French amod food NOUN ADJ []
# food attr is AUX NOUN [the, best, French, find]
# you nsubj find VERB PRON []
# will aux find VERB AUX []
# find relcl food NOUN VERB [you, will, in]
# in prep find VERB ADP [area]
# the det area NOUN DET []
# area pobj in ADP NOUN [the]
# . punct is AUX PUNCT []
# Right advmod off ADP ADV []
# off prep is AUX ADP [Right, L]
# the det L PROPN DET []
# L pobj off ADP PROPN [the, in]
# in prep L PROPN ADP [Brooklyn]
# Brooklyn pobj in ADP PROPN []
# this nsubj is AUX PRON []
# is ROOT is AUX AUX [off, this, place, .]
# a det place NOUN DET []
# nice amod place NOUN ADJ []
# cozy amod place NOUN ADJ []
# place attr is AUX NOUN [a, nice, cozy, with]
# with prep place NOUN ADP [pizza]
# good amod pizza NOUN ADJ []
# pizza pobj with ADP NOUN [good]
# . punct is AUX PUNCT []
# Right advmod off ADP ADV []
# off prep is AUX ADP [Right, L]
# the det L PROPN DET []
# L pobj off ADP PROPN [the, in]
# in prep L PROPN ADP [Brooklyn]
# Brooklyn pobj in ADP PROPN []
# this nsubj is AUX PRON []
# is ROOT is AUX AUX [off, this, place, .]
# a det place NOUN DET []
# nice amod place NOUN ADJ []
# cozy amod place NOUN ADJ []
# place attr is AUX NOUN [a, nice, cozy, with]
# with prep place NOUN ADP [pizza]
# good amod pizza NOUN ADJ []
# pizza pobj with ADP NOUN [good]
# . punct is AUX PUNCT []
# Le compound Pinard PROPN PROPN []
# Pere compound Pinard PROPN PROPN []
# Pinard nsubj has VERB PROPN [Le, Pere]
# has ROOT has VERB VERB [Pinard, menu, .]
# a det menu NOUN DET []
# $ nmod 15 NUM SYM []
# 15 nummod menu NOUN NUM [$]
# pre amod menu NOUN ADJ []
# - amod menu NOUN ADJ []
# theater amod menu NOUN ADJ []
# menu dobj has VERB NOUN [a, 15, pre, -, theater, is]
# that nsubj is AUX PRON []
# is relcl menu NOUN AUX [that, outstanding]
# outstanding acomp is AUX ADJ []
# . punct has VERB PUNCT []
# I nsubj ordered VERB PRON []
# also advmod ordered VERB ADV []
# ordered ROOT ordered VERB VERB [I, also, for, forgot]
# for prep ordered VERB ADP [delivery]
# delivery pobj for ADP NOUN [and]
# and cc delivery NOUN CCONJ []
# the det restaurant NOUN DET []
# restaurant nsubj forgot VERB NOUN [the]
# forgot ccomp ordered VERB VERB [restaurant, order, .]
# half predet order NOUN DET []
# the det order NOUN DET []
# order dobj forgot VERB NOUN [half, the]
# . punct forgot VERB PUNCT []
# I nsubj ordered VERB PRON []
# also advmod ordered VERB ADV []
# ordered ROOT ordered VERB VERB [I, also, for, forgot]
# for prep ordered VERB ADP [delivery]
# delivery pobj for ADP NOUN [and]
# and cc delivery NOUN CCONJ []
# the det restaurant NOUN DET []
# restaurant nsubj forgot VERB NOUN [the]
# forgot ccomp ordered VERB VERB [restaurant, order, .]
# half predet order NOUN DET []
# the det order NOUN DET []
# order dobj forgot VERB NOUN [half, the]
# . punct forgot VERB PUNCT []

# %%
for sentence in sentences:
  doc = nlp(sentence)
  descriptive_term = ''
  for token in doc:
    if token.pos_ == 'ADJ':
      descriptive_term = token
  print(sentence)
  print(descriptive_term)
# Out:
# But the staff was so horrible to us.
# horrible
# To be completely fair, the only redeeming factor was the food, which was above average, but couldn't make up for all the other deficiencies of Teodora.
# other
# The food is uniformly exceptional, with a very capable kitchen which will proudly whip up whatever you feel like eating, whether it's on the menu or not.
# capable
# The food is uniformly exceptional, with a very capable kitchen which will proudly whip up whatever you feel like eating, whether it's on the menu or not.
# capable
# The food is uniformly exceptional, with a very capable kitchen which will proudly whip up whatever you feel like eating, whether it's on the menu or not.
# capable
# Not only was the food outstanding, but the little 'perks' were great.
# great
# Not only was the food outstanding, but the little 'perks' were great.
# great
# Our agreed favorite is the orrechiete with sausage and chicken (usually the waiters are kind enough to split the dish in half so you get to sample both meats).
# enough
# Our agreed favorite is the orrechiete with sausage and chicken (usually the waiters are kind enough to split the dish in half so you get to sample both meats).
# enough
# Our agreed favorite is the orrechiete with sausage and chicken (usually the waiters are kind enough to split the dish in half so you get to sample both meats).
# enough
# Our agreed favorite is the orrechiete with sausage and chicken (usually the waiters are kind enough to split the dish in half so you get to sample both meats).
# enough
# The Bagels have an outstanding taste with a terrific texture, both chewy yet not gummy.
# gummy
# Nevertheless the food itself is pretty good.
# good
# They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# hot
# They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# hot
# They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# hot
# They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# hot
# They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# hot
# They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# hot
# They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# hot
# It took half an hour to get our check, which was perfect since we could sit, have drinks and talk!
# perfect
# It took half an hour to get our check, which was perfect since we could sit, have drinks and talk!
# perfect
# The design and atmosphere is just as good.
# good
# The design and atmosphere is just as good.
# good
# He has visited Thailand and is quite expert on the cuisine.
#
# The pizza is the best if you like thin crusted pizza.
# thin
# The pizza is the best if you like thin crusted pizza.
# thin
# All the money went into the interior decoration, none of it went to the chefs.
# interior
# All the money went into the interior decoration, none of it went to the chefs.
# interior
# The seats are uncomfortable if you are sitting against the wall on wooden benches.
# wooden
# I asked for seltzer with lime, no ice.
#
# Don't go alone---even two people isn't enough for the whole experience, with pickles and a selection of meats and seafoods.
# whole
# Don't go alone---even two people isn't enough for the whole experience, with pickles and a selection of meats and seafoods.
# whole
# My suggestion is to eat family style because you'll want to try the other dishes.
# other
# My suggestion is to eat family style because you'll want to try the other dishes.
# other
# Best of all is the warm vibe, the owner is super friendly and service is fast.
# fast
# Best of all is the warm vibe, the owner is super friendly and service is fast.
# fast
# Best of all is the warm vibe, the owner is super friendly and service is fast.
# fast
# Faan's got a great concept but a little rough on the delivery.
# rough
# From the incredible food, to the warm atmosphere, to the friendly service, this downtown neighborhood spot doesn't miss a beat.
# friendly
# From the incredible food, to the warm atmosphere, to the friendly service, this downtown neighborhood spot doesn't miss a beat.
# friendly
# From the incredible food, to the warm atmosphere, to the friendly service, this downtown neighborhood spot doesn't miss a beat.
# friendly
# Great food at REASONABLE prices, makes for an evening that can't be beat!
# REASONABLE
# Great food at REASONABLE prices, makes for an evening that can't be beat!
# REASONABLE
# this little place has a cute interior decor and affordable city prices.
# affordable
# this little place has a cute interior decor and affordable city prices.
# affordable
# Two words: Free wine.
# Free
# The price is reasonable although the service is poor.
# poor
# The price is reasonable although the service is poor.
# poor
# The quantity is also very good, you will come out satisfied.
# satisfied
# I stumbled upon this second floor walk-up two Fridays ago when I was with two friends in town from L.A. Being serious sushi lovers, we sat at the sushi bar to be closer to the action.
# closer
# I stumbled upon this second floor walk-up two Fridays ago when I was with two friends in town from L.A. Being serious sushi lovers, we sat at the sushi bar to be closer to the action.
# closer
# The fried rice is amazing here.
# amazing
# Three courses - choices include excellent mussels, puff pastry goat cheese and salad with a delicious dressing, and a hanger steak au poivre that is out of this world.
# hanger
# Three courses - choices include excellent mussels, puff pastry goat cheese and salad with a delicious dressing, and a hanger steak au poivre that is out of this world.
# hanger
# Three courses - choices include excellent mussels, puff pastry goat cheese and salad with a delicious dressing, and a hanger steak au poivre that is out of this world.
# hanger
# Three courses - choices include excellent mussels, puff pastry goat cheese and salad with a delicious dressing, and a hanger steak au poivre that is out of this world.
# hanger
# Three courses - choices include excellent mussels, puff pastry goat cheese and salad with a delicious dressing, and a hanger steak au poivre that is out of this world.
# hanger
# it's a perfect place to have a amanzing indian food.
# indian
# The place is so cool and the service is prompt and curtious.
# curtious
# The place is so cool and the service is prompt and curtious.
# curtious
# At the end you're left with a mild broth with noodles that you can slurp out of a cup.
# mild
# I just wonder how you can have such a delicious meal for such little money.
# little
# I just wonder how you can have such a delicious meal for such little money.
# little
# The food was delicious but do not come here on a empty stomach.
# empty
# The wine list is excellent.
# excellent
# Ive been to many Thai restaurants in Manhattan before, and Toons is by far the best Thai food Ive had (except for my mom's of course).
# Thai
# They wouldnt even let me finish my glass of wine before offering another.
#
# Whem asked, we had to ask more detailed questions so that we knew what the specials were.
# detailed
# This is a consistently great place to dine for lunch or dinner.
# great
# This is a consistently great place to dine for lunch or dinner.
# great
# This is a consistently great place to dine for lunch or dinner.
# great
# Nice atmosphere, the service was very pleasant and the desert was good.
# good
# Nice atmosphere, the service was very pleasant and the desert was good.
# good
# Nice atmosphere, the service was very pleasant and the desert was good.
# good
# After really enjoying ourselves at the bar we sat down at a table and had dinner.
#
# After really enjoying ourselves at the bar we sat down at a table and had dinner.
#
# After really enjoying ourselves at the bar we sat down at a table and had dinner.
#
# Fabulous service, fantastic food, and a chilled out atmosphere and environment.
# fantastic
# Fabulous service, fantastic food, and a chilled out atmosphere and environment.
# fantastic
# Fabulous service, fantastic food, and a chilled out atmosphere and environment.
# fantastic
# Fabulous service, fantastic food, and a chilled out atmosphere and environment.
# fantastic
# Try the lasagnette appetizer.
#
# I liked the beer selection!
#
# Great food, good size menu, great service and an unpretensious setting.
# unpretensious
# Great food, good size menu, great service and an unpretensious setting.
# unpretensious
# Great food, good size menu, great service and an unpretensious setting.
# unpretensious
# Great food, good size menu, great service and an unpretensious setting.
# unpretensious
# Go here for a romantic dinner but not for an all out wow dining experience.
# romantic
# Go here for a romantic dinner but not for an all out wow dining experience.
# romantic
# I grew up eating Dosa and have yet to find a place in NY to satisfy my taste buds.
#
# Wine list selection is good and wine-by-the-glass was generously filled to the top.
# good
# Wine list selection is good and wine-by-the-glass was generously filled to the top.
# good
# With the great variety on the menu , I eat here often and never get bored .
# bored
# The menu is very limited - i think we counted 4 or 5 entrees.
# limited
# The menu is very limited - i think we counted 4 or 5 entrees.
# limited
# The menu is limited but almost all of the dishes are excellent.
# excellent
# The menu is limited but almost all of the dishes are excellent.
# excellent
# Not too crazy about their sake martini.
# crazy
# Great bagels, spreads and a good place to hang out in.
# good
# Great bagels, spreads and a good place to hang out in.
# good
# The service varys from day to day- sometimes they're very nice, and sometimes not.
# nice
# One thing I liked about this place is that I never felt rushed or pressured to give up my table ot incoming guests.
# incoming
# Unfortunately, the food is outstanding, but everything else about this restaurant is the pits.
# outstanding
# We always have a delicious meal and always leave feeling satisfied.
# satisfied
# Dip the ingredients in with your chopsticks, swirl them around, and eat.
#
# Dip the ingredients in with your chopsticks, swirl them around, and eat.
#
# First went here to enjoy their garden terrace.
#
# The pizza was pretty good and huge.
# huge
# The cuisine from what I've gathered is authentic Taiwanese, though its very different from what I've been accustomed to in Taipei.
# different
# I almost hesititate to write a review because the atmosphere was so great and I would hate for it too become to crowded.
# great
# They are often crowded on the weekends but they are efficient and accurate with their service.
# accurate
# They are often crowded on the weekends but they are efficient and accurate with their service.
# accurate
# All my co-workers were amazed at how small the dish was.
# small
# The atmosphere is unheralded, the service impecible, and the food magnificant.
# impecible
# The atmosphere is unheralded, the service impecible, and the food magnificant.
# impecible
# The atmosphere is unheralded, the service impecible, and the food magnificant.
# impecible
# We ordered the special, grilled branzino, that was so infused with bone, it was difficult to eat.
# difficult
# The wait staff is friendly, and the food has gotten better and better!
# better
# The wait staff is friendly, and the food has gotten better and better!
# better
# It may be a bit packed on weekends, but the vibe is good and it is the best French food you will find in the area.
# French
# It may be a bit packed on weekends, but the vibe is good and it is the best French food you will find in the area.
# French
# It may be a bit packed on weekends, but the vibe is good and it is the best French food you will find in the area.
# French
# Right off the L in Brooklyn this is a nice cozy place with good pizza.
# good
# Right off the L in Brooklyn this is a nice cozy place with good pizza.
# good
# Le Pere Pinard has a $15 pre-theater menu that is outstanding.
# outstanding
# I also ordered for delivery and the restaurant forgot half the order.
#
# I also ordered for delivery and the restaurant forgot half the order.

# %%
#assumption: features of products and services are mostly nouns/noun compounds
#step 1: extract the aspect candiates
aspects = []
for sentence in sentences:
  doc = nlp(sentence)
  descriptive_term = ''
  target = ''
  for token in doc:
    if token.dep_ == 'nsubj' and token.pos_ == 'NOUN':
        target = token.text
    if token.dep_ == "compound":
        target = token.text+token.head.text
    if token.pos_ == 'ADJ':
      descriptive_term = token.text
  aspects.append({'aspect': target,'description': descriptive_term})

# %%
aspects

# %%
#considering reviews pertaining to only food and service
#step 2: classifying if "aspect" or "non-aspect" i.e., considering only the aspect candidates of the lot.
pizza_reviews = []
service_reviews = []
for aspect in aspects:
    if aspect['aspect'] == "pizza" or aspect['aspect'] == "dish" or aspect['aspect'] == "food" or aspect['aspect'] == "desert" or aspect['aspect'] == "PerePinard":
        pizza_reviews.append(aspect)
    elif aspect['aspect'] == "waiters" or aspect['aspect'] == "service" or aspect['aspect'] == "menu":
        service_reviews.append(aspect)
    else:
        continue

# %%
pizza_reviews
# Out:
# [{'aspect': 'food', 'description': 'capable'},
#  {'aspect': 'food', 'description': 'capable'},
#  {'aspect': 'food', 'description': 'capable'},
#  {'aspect': 'food', 'description': 'good'},
#  {'aspect': 'pizza', 'description': 'thin'},
#  {'aspect': 'pizza', 'description': 'thin'},
#  {'aspect': 'food', 'description': 'REASONABLE'},
#  {'aspect': 'food', 'description': 'REASONABLE'},
#  {'aspect': 'food', 'description': 'empty'},
#  {'aspect': 'desert', 'description': 'good'},
#  {'aspect': 'desert', 'description': 'good'},
#  {'aspect': 'desert', 'description': 'good'},
#  {'aspect': 'food', 'description': 'outstanding'},
#  {'aspect': 'pizza', 'description': 'huge'},
#  {'aspect': 'dish', 'description': 'small'},
#  {'aspect': 'food', 'description': 'better'},
#  {'aspect': 'food', 'description': 'better'},
#  {'aspect': 'PerePinard', 'description': 'outstanding'}]

# %%
restaurant_reviews = [dict(t) for t in {tuple(aspect.items()) for aspect in pizza_reviews}]

# %%
restaurant_reviews.extend([dict(t) for t in {tuple(aspect.items()) for aspect in service_reviews}])

# %%
restaurant_reviews
# Out:
# [{'aspect': 'pizza', 'description': 'huge'},
#  {'aspect': 'PerePinard', 'description': 'outstanding'},
#  {'aspect': 'food', 'description': 'good'},
#  {'aspect': 'desert', 'description': 'good'},
#  {'aspect': 'dish', 'description': 'small'},
#  {'aspect': 'food', 'description': 'outstanding'},
#  {'aspect': 'pizza', 'description': 'thin'},
#  {'aspect': 'food', 'description': 'capable'},
#  {'aspect': 'food', 'description': 'REASONABLE'},
#  {'aspect': 'food', 'description': 'better'},
#  {'aspect': 'food', 'description': 'empty'},
#  {'aspect': 'service', 'description': 'fast'},
#  {'aspect': 'service', 'description': 'curtious'},
#  {'aspect': 'service', 'description': 'poor'},
#  {'aspect': 'menu', 'description': 'excellent'},
#  {'aspect': 'menu', 'description': 'limited'},
#  {'aspect': 'waiters', 'description': 'enough'}]

# %%
# step 3: associate a polarity score to each extracted aspect. (here using TextBlob)
from textblob import TextBlob
map_dict = restaurant_reviews.copy()
for aspect in restaurant_reviews:
  aspect['sentiment'] = TextBlob(aspect['description']).sentiment
restaurant_reviews
# Out:
# [{'aspect': 'pizza',
#   'description': 'huge',
#   'sentiment': Sentiment(polarity=0.39999999999999997, subjectivity=0.9)},
#  {'aspect': 'PerePinard',
#   'description': 'outstanding',
#   'sentiment': Sentiment(polarity=0.5, subjectivity=0.875)},
#  {'aspect': 'food',
#   'description': 'good',
#   'sentiment': Sentiment(polarity=0.7, subjectivity=0.6000000000000001)},
#  {'aspect': 'desert',
#   'description': 'good',
#   'sentiment': Sentiment(polarity=0.7, subjectivity=0.6000000000000001)},
#  {'aspect': 'dish',
#   'description': 'small',
#   'sentiment': Sentiment(polarity=-0.25, subjectivity=0.4)},
#  {'aspect': 'food',
#   'description': 'outstanding',
#   'sentiment': Sentiment(polarity=0.5, subjectivity=0.875)},
#  {'aspect': 'pizza',
#   'description': 'thin',
#   'sentiment': Sentiment(polarity=-0.4, subjectivity=0.8500000000000001)},
#  {'aspect': 'food',
#   'description': 'capable',
#   'sentiment': Sentiment(polarity=0.2, subjectivity=0.4)},
#  {'aspect': 'food',
#   'description': 'REASONABLE',
#   'sentiment': Sentiment(polarity=0.2, subjectivity=0.6)},
#  {'aspect': 'food',
#   'description': 'better',
#   'sentiment': Sentiment(polarity=0.5, subjectivity=0.5)},
#  {'aspect': 'food',
#   'description': 'empty',
#   'sentiment': Sentiment(polarity=-0.1, subjectivity=0.5)},
#  {'aspect': 'service',
#   'description': 'fast',
#   'sentiment': Sentiment(polarity=0.2, subjectivity=0.6)},
#  {'aspect': 'service',
#   'description': 'curtious',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': 'service',
#   'description': 'poor',
#   'sentiment': Sentiment(polarity=-0.4, subjectivity=0.6)},
#  {'aspect': 'menu',
#   'description': 'excellent',
#   'sentiment': Sentiment(polarity=1.0, subjectivity=1.0)},
#  {'aspect': 'menu',
#   'description': 'limited',
#   'sentiment': Sentiment(polarity=-0.07142857142857142, subjectivity=0.14285714285714285)},
#  {'aspect': 'waiters',
#   'description': 'enough',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.5)}]

# %%
# step 3: associate a polarity score to each extracted aspect. (here using VADER)
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
def get_sentiment(text):
    scores = analyzer.polarity_scores(text)
    sentiment = "positive" if scores['pos'] >= 0.5 else "negative"
    return sentiment

def get_score(text):
    scores = analyzer.polarity_scores(text)
    score = scores['pos'] if scores['pos'] >= 0.5 else scores['neg']
    return score

# %%
for aspect in restaurant_reviews:
    aspect['VADER sentiment'] = get_sentiment(aspect['description'])
    aspect['VADER score'] = get_score(aspect['description'])
restaurant_reviews
# Out:
# [{'aspect': 'pizza',
#   'description': 'huge',
#   'sentiment': Sentiment(polarity=0.39999999999999997, subjectivity=0.9),
#   'VADER sentiment': 'positive',
#   'VADER score': 1.0},
#  {'aspect': 'PerePinard',
#   'description': 'outstanding',
#   'sentiment': Sentiment(polarity=0.5, subjectivity=0.875),
#   'VADER sentiment': 'positive',
#   'VADER score': 1.0},
#  {'aspect': 'food',
#   'description': 'good',
#   'sentiment': Sentiment(polarity=0.7, subjectivity=0.6000000000000001),
#   'VADER sentiment': 'positive',
#   'VADER score': 1.0},
#  {'aspect': 'desert',
#   'description': 'good',
#   'sentiment': Sentiment(polarity=0.7, subjectivity=0.6000000000000001),
#   'VADER sentiment': 'positive',
#   'VADER score': 1.0},
#  {'aspect': 'dish',
#   'description': 'small',
#   'sentiment': Sentiment(polarity=-0.25, subjectivity=0.4),
#   'VADER sentiment': 'negative',
#   'VADER score': 0.0},
#  {'aspect': 'food',
#   'description': 'outstanding',
#   'sentiment': Sentiment(polarity=0.5, subjectivity=0.875),
#   'VADER sentiment': 'positive',
#   'VADER score': 1.0},
#  {'aspect': 'pizza',
#   'description': 'thin',
#   'sentiment': Sentiment(polarity=-0.4, subjectivity=0.8500000000000001),
#   'VADER sentiment': 'negative',
#   'VADER score': 0.0},
#  {'aspect': 'food',
#   'description': 'capable',
#   'sentiment': Sentiment(polarity=0.2, subjectivity=0.4),
#   'VADER sentiment': 'positive',
#   'VADER score': 1.0},
#  {'aspect': 'food',
#   'description': 'REASONABLE',
#   'sentiment': Sentiment(polarity=0.2, subjectivity=0.6),
#   'VADER sentiment': 'negative',
#   'VADER score': 0.0},
#  {'aspect': 'food',
#   'description': 'better',
#   'sentiment': Sentiment(polarity=0.5, subjectivity=0.5),
#   'VADER sentiment': 'positive',
#   'VADER score': 1.0},
#  {'aspect': 'food',
#   'description': 'empty',
#   'sentiment': Sentiment(polarity=-0.1, subjectivity=0.5),
#   'VADER sentiment': 'negative',
#   'VADER score': 1.0},
#  {'aspect': 'service',
#   'description': 'fast',
#   'sentiment': Sentiment(polarity=0.2, subjectivity=0.6),
#   'VADER sentiment': 'negative',
#   'VADER score': 0.0},
#  {'aspect': 'service',
#   'description': 'curtious',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'VADER sentiment': 'negative',
#   'VADER score': 0.0},
#  {'aspect': 'service',
#   'description': 'poor',
#   'sentiment': Sentiment(polarity=-0.4, subjectivity=0.6),
#   'VADER sentiment': 'negative',
#   'VADER score': 1.0},
#  {'aspect': 'menu',
#   'description': 'excellent',
#   'sentiment': Sentiment(polarity=1.0, subjectivity=1.0),
#   'VADER sentiment': 'positive',
#   'VADER score': 1.0},
#  {'aspect': 'menu',
#   'description': 'limited',
#   'sentiment': Sentiment(polarity=-0.07142857142857142, subjectivity=0.14285714285714285),
#   'VADER sentiment': 'negative',
#   'VADER score': 1.0},
#  {'aspect': 'waiters',
#   'description': 'enough',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.5),
#   'VADER sentiment': 'negative',
#   'VADER score': 0.0}]
